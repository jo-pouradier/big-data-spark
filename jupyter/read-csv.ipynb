# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.getOrCreate()

# %%
file_path = "./work/data/airports.csv"
csv_df = spark.read.csv(file_path)
csv_df.printSchema()
csv_df.show(truncate=False, vertical=True)
# Out:
# root
#  |-- _c0: string (nullable = true)
#  |-- _c1: string (nullable = true)
#  |-- _c2: string (nullable = true)
#  |-- _c3: string (nullable = true)
#  |-- _c4: string (nullable = true)
#  |-- _c5: string (nullable = true)
#  |-- _c6: string (nullable = true)
#
# -RECORD 0------------------------------------------
#  _c0 | IATA_CODE
#  _c1 | AIRPORT
#  _c2 | CITY
#  _c3 | STATE
#  _c4 | COUNTRY
#  _c5 | LATITUDE
#  _c6 | LONGITUDE
# -RECORD 1------------------------------------------
#  _c0 | ABE
#  _c1 | Lehigh Valley International Airport
#  _c2 | Allentown
#  _c3 | PA
#  _c4 | USA
#  _c5 | 40.65236
#  _c6 | -75.44040
# -RECORD 2------------------------------------------
#  _c0 | ABI
#  _c1 | Abilene Regional Airport
#  _c2 | Abilene
#  _c3 | TX
#  _c4 | USA
#  _c5 | 32.41132
#  _c6 | -99.68190
# -RECORD 3------------------------------------------
#  _c0 | ABQ
#  _c1 | Albuquerque International Sunport
#  _c2 | Albuquerque
#  _c3 | NM
#  _c4 | USA
#  _c5 | 35.04022
#  _c6 | -106.60919
# -RECORD 4------------------------------------------
#  _c0 | ABR
#  _c1 | Aberdeen Regional Airport
#  _c2 | Aberdeen
#  _c3 | SD
#  _c4 | USA
#  _c5 | 45.44906
#  _c6 | -98.42183
# -RECORD 5------------------------------------------
#  _c0 | ABY
#  _c1 | Southwest Georgia Regional Airport
#  _c2 | Albany
#  _c3 | GA
#  _c4 | USA
#  _c5 | 31.53552
#  _c6 | -84.19447
# -RECORD 6------------------------------------------
#  _c0 | ACK
#  _c1 | Nantucket Memorial Airport
#  _c2 | Nantucket
#  _c3 | MA
#  _c4 | USA
#  _c5 | 41.25305
#  _c6 | -70.06018
# -RECORD 7------------------------------------------
#  _c0 | ACT
#  _c1 | Waco Regional Airport
#  _c2 | Waco
#  _c3 | TX
#  _c4 | USA
#  _c5 | 31.61129
#  _c6 | -97.23052
# -RECORD 8------------------------------------------
#  _c0 | ACV
#  _c1 | Arcata Airport
#  _c2 | Arcata/Eureka
#  _c3 | CA
#  _c4 | USA
#  _c5 | 40.97812
#  _c6 | -124.10862
# -RECORD 9------------------------------------------
#  _c0 | ACY
#  _c1 | Atlantic City International Airport
#  _c2 | Atlantic City
#  _c3 | NJ
#  _c4 | USA
#  _c5 | 39.45758
#  _c6 | -74.57717
# -RECORD 10-----------------------------------------
#  _c0 | ADK
#  _c1 | Adak Airport
#  _c2 | Adak
#  _c3 | AK
#  _c4 | USA
#  _c5 | 51.87796
#  _c6 | -176.64603
# -RECORD 11-----------------------------------------
#  _c0 | ADQ
#  _c1 | Kodiak Airport
#  _c2 | Kodiak
#  _c3 | AK
#  _c4 | USA
#  _c5 | 57.74997
#  _c6 | -152.49386
# -RECORD 12-----------------------------------------
#  _c0 | AEX
#  _c1 | Alexandria International Airport
#  _c2 | Alexandria
#  _c3 | LA
#  _c4 | USA
#  _c5 | 31.32737
#  _c6 | -92.54856
# -RECORD 13-----------------------------------------
#  _c0 | AGS
#  _c1 | Augusta Regional Airport (Bush Field)
#  _c2 | Augusta
#  _c3 | GA
#  _c4 | USA
#  _c5 | 33.36996
#  _c6 | -81.96450
# -RECORD 14-----------------------------------------
#  _c0 | AKN
#  _c1 | King Salmon Airport
#  _c2 | King Salmon
#  _c3 | AK
#  _c4 | USA
#  _c5 | 58.67680
#  _c6 | -156.64922
# -RECORD 15-----------------------------------------
#  _c0 | ALB
#  _c1 | Albany International Airport
#  _c2 | Albany
#  _c3 | NY
#  _c4 | USA
#  _c5 | 42.74812
#  _c6 | -73.80298
# -RECORD 16-----------------------------------------
#  _c0 | ALO
#  _c1 | Waterloo Regional Airport
#  _c2 | Waterloo
#  _c3 | IA
#  _c4 | USA
#  _c5 | 42.55708
#  _c6 | -92.40034
# -RECORD 17-----------------------------------------
#  _c0 | AMA
#  _c1 | Rick Husband Amarillo International Airport
#  _c2 | Amarillo
#  _c3 | TX
#  _c4 | USA
#  _c5 | 35.21937
#  _c6 | -101.70593
# -RECORD 18-----------------------------------------
#  _c0 | ANC
#  _c1 | Ted Stevens Anchorage International Airport
#  _c2 | Anchorage
#  _c3 | AK
#  _c4 | USA
#  _c5 | 61.17432
#  _c6 | -149.99619
# -RECORD 19-----------------------------------------
#  _c0 | APN
#  _c1 | Alpena County Regional Airport
#  _c2 | Alpena
#  _c3 | MI
#  _c4 | USA
#  _c5 | 45.07807
#  _c6 | -83.56029
# only showing top 20 rows

# %% [markdown]
# Above we dont have the columns names, let's add them

# %%
csv_header_df = spark.read.option("header", True).csv(file_path)
csv_header_df.printSchema()
csv_header_df.show(truncate=False, vertical=True)
# Out:
# root
#  |-- IATA_CODE: string (nullable = true)
#  |-- AIRPORT: string (nullable = true)
#  |-- CITY: string (nullable = true)
#  |-- STATE: string (nullable = true)
#  |-- COUNTRY: string (nullable = true)
#  |-- LATITUDE: string (nullable = true)
#  |-- LONGITUDE: string (nullable = true)
#
# -RECORD 0------------------------------------------------
#  IATA_CODE | ABE
#  AIRPORT   | Lehigh Valley International Airport
#  CITY      | Allentown
#  STATE     | PA
#  COUNTRY   | USA
#  LATITUDE  | 40.65236
#  LONGITUDE | -75.44040
# -RECORD 1------------------------------------------------
#  IATA_CODE | ABI
#  AIRPORT   | Abilene Regional Airport
#  CITY      | Abilene
#  STATE     | TX
#  COUNTRY   | USA
#  LATITUDE  | 32.41132
#  LONGITUDE | -99.68190
# -RECORD 2------------------------------------------------
#  IATA_CODE | ABQ
#  AIRPORT   | Albuquerque International Sunport
#  CITY      | Albuquerque
#  STATE     | NM
#  COUNTRY   | USA
#  LATITUDE  | 35.04022
#  LONGITUDE | -106.60919
# -RECORD 3------------------------------------------------
#  IATA_CODE | ABR
#  AIRPORT   | Aberdeen Regional Airport
#  CITY      | Aberdeen
#  STATE     | SD
#  COUNTRY   | USA
#  LATITUDE  | 45.44906
#  LONGITUDE | -98.42183
# -RECORD 4------------------------------------------------
#  IATA_CODE | ABY
#  AIRPORT   | Southwest Georgia Regional Airport
#  CITY      | Albany
#  STATE     | GA
#  COUNTRY   | USA
#  LATITUDE  | 31.53552
#  LONGITUDE | -84.19447
# -RECORD 5------------------------------------------------
#  IATA_CODE | ACK
#  AIRPORT   | Nantucket Memorial Airport
#  CITY      | Nantucket
#  STATE     | MA
#  COUNTRY   | USA
#  LATITUDE  | 41.25305
#  LONGITUDE | -70.06018
# -RECORD 6------------------------------------------------
#  IATA_CODE | ACT
#  AIRPORT   | Waco Regional Airport
#  CITY      | Waco
#  STATE     | TX
#  COUNTRY   | USA
#  LATITUDE  | 31.61129
#  LONGITUDE | -97.23052
# -RECORD 7------------------------------------------------
#  IATA_CODE | ACV
#  AIRPORT   | Arcata Airport
#  CITY      | Arcata/Eureka
#  STATE     | CA
#  COUNTRY   | USA
#  LATITUDE  | 40.97812
#  LONGITUDE | -124.10862
# -RECORD 8------------------------------------------------
#  IATA_CODE | ACY
#  AIRPORT   | Atlantic City International Airport
#  CITY      | Atlantic City
#  STATE     | NJ
#  COUNTRY   | USA
#  LATITUDE  | 39.45758
#  LONGITUDE | -74.57717
# -RECORD 9------------------------------------------------
#  IATA_CODE | ADK
#  AIRPORT   | Adak Airport
#  CITY      | Adak
#  STATE     | AK
#  COUNTRY   | USA
#  LATITUDE  | 51.87796
#  LONGITUDE | -176.64603
# -RECORD 10-----------------------------------------------
#  IATA_CODE | ADQ
#  AIRPORT   | Kodiak Airport
#  CITY      | Kodiak
#  STATE     | AK
#  COUNTRY   | USA
#  LATITUDE  | 57.74997
#  LONGITUDE | -152.49386
# -RECORD 11-----------------------------------------------
#  IATA_CODE | AEX
#  AIRPORT   | Alexandria International Airport
#  CITY      | Alexandria
#  STATE     | LA
#  COUNTRY   | USA
#  LATITUDE  | 31.32737
#  LONGITUDE | -92.54856
# -RECORD 12-----------------------------------------------
#  IATA_CODE | AGS
#  AIRPORT   | Augusta Regional Airport (Bush Field)
#  CITY      | Augusta
#  STATE     | GA
#  COUNTRY   | USA
#  LATITUDE  | 33.36996
#  LONGITUDE | -81.96450
# -RECORD 13-----------------------------------------------
#  IATA_CODE | AKN
#  AIRPORT   | King Salmon Airport
#  CITY      | King Salmon
#  STATE     | AK
#  COUNTRY   | USA
#  LATITUDE  | 58.67680
#  LONGITUDE | -156.64922
# -RECORD 14-----------------------------------------------
#  IATA_CODE | ALB
#  AIRPORT   | Albany International Airport
#  CITY      | Albany
#  STATE     | NY
#  COUNTRY   | USA
#  LATITUDE  | 42.74812
#  LONGITUDE | -73.80298
# -RECORD 15-----------------------------------------------
#  IATA_CODE | ALO
#  AIRPORT   | Waterloo Regional Airport
#  CITY      | Waterloo
#  STATE     | IA
#  COUNTRY   | USA
#  LATITUDE  | 42.55708
#  LONGITUDE | -92.40034
# -RECORD 16-----------------------------------------------
#  IATA_CODE | AMA
#  AIRPORT   | Rick Husband Amarillo International Airport
#  CITY      | Amarillo
#  STATE     | TX
#  COUNTRY   | USA
#  LATITUDE  | 35.21937
#  LONGITUDE | -101.70593
# -RECORD 17-----------------------------------------------
#  IATA_CODE | ANC
#  AIRPORT   | Ted Stevens Anchorage International Airport
#  CITY      | Anchorage
#  STATE     | AK
#  COUNTRY   | USA
#  LATITUDE  | 61.17432
#  LONGITUDE | -149.99619
# -RECORD 18-----------------------------------------------
#  IATA_CODE | APN
#  AIRPORT   | Alpena County Regional Airport
#  CITY      | Alpena
#  STATE     | MI
#  COUNTRY   | USA
#  LATITUDE  | 45.07807
#  LONGITUDE | -83.56029
# -RECORD 19-----------------------------------------------
#  IATA_CODE | ASE
#  AIRPORT   | Aspen-Pitkin County Airport
#  CITY      | Aspen
#  STATE     | CO
#  COUNTRY   | USA
#  LATITUDE  | 39.22316
#  LONGITUDE | -106.86885
# only showing top 20 rows

# %%
csv_clean1_df = spark.read.option("header", True).option("inferschema", True).csv(file_path)
csv_clean1_df.printSchema()
# Out:
# root
#  |-- IATA_CODE: string (nullable = true)
#  |-- AIRPORT: string (nullable = true)
#  |-- CITY: string (nullable = true)
#  |-- STATE: string (nullable = true)
#  |-- COUNTRY: string (nullable = true)
#  |-- LATITUDE: double (nullable = true)
#  |-- LONGITUDE: double (nullable = true)

# %%
from pyspark.sql.types import *
import pyspark.sql.functions as F

schema = StructType([
 StructField("IATA_CODE", StringType(), False),
 StructField("AIRPORT", StringType(), False),
 StructField("CITY", StringType(), False),
 StructField("STATE", StringType(), False),
 StructField("COUNTRY", StringType(), False),
 StructField("LATITUDE", FloatType(), False),
 StructField("LONGITUDE", FloatType(), False)
])

csv_clean2_df = spark.read.option("header", True).schema(schema).csv(file_path)
csv_clean2_df.printSchema()
# Out:
# root
#  |-- IATA_CODE: string (nullable = true)
#  |-- AIRPORT: string (nullable = true)
#  |-- CITY: string (nullable = true)
#  |-- STATE: string (nullable = true)
#  |-- COUNTRY: string (nullable = true)
#  |-- LATITUDE: float (nullable = true)
#  |-- LONGITUDE: float (nullable = true)

# %% [markdown]
# ## Ajout de colonnes

# %%
new_df = csv_clean2_df.withColumn("NEWCOL", F.lit("Hello"))
new_df = csv_clean2_df.withColumn("NEWCOL", F.lit("123.456").cast(FloatType()))
new_df = csv_clean2_df.withColumn("NEWCOL", F.lower(F.col("IATA_CODE")))
new_df = csv_clean2_df.withColumn("NEWCOL", F.to_date(F.lit('2024-01-30 12:56:33'), 'yyyy-MM-dd HH:mm:ss'))
new_df.printSchema()
# Out:
# root
#  |-- IATA_CODE: string (nullable = true)
#  |-- AIRPORT: string (nullable = true)
#  |-- CITY: string (nullable = true)
#  |-- STATE: string (nullable = true)
#  |-- COUNTRY: string (nullable = true)
#  |-- LATITUDE: float (nullable = true)
#  |-- LONGITUDE: float (nullable = true)
#  |-- NEWCOL: date (nullable = true)

# %% [markdown]
# ## Renommage et Drop

# %%
new_df = csv_clean2_df.withColumnRenamed("IATA_CODE", "NEW_IATA_CODE")
new_df = csv_clean2_df.drop("LATITUDE", "LONGITUDE")
new_df.printSchema()
# Out:
# root
#  |-- IATA_CODE: string (nullable = true)
#  |-- AIRPORT: string (nullable = true)
#  |-- CITY: string (nullable = true)
#  |-- STATE: string (nullable = true)
#  |-- COUNTRY: string (nullable = true)

# %% [markdown]
# ## Operations Courantes

# %% [markdown]
# ### Select

# %%
new_df = csv_clean2_df.select("IATA_CODE", "AIRPORT")
new_df.head()
# Out:
# Row(IATA_CODE='ABE', AIRPORT='Lehigh Valley International Airport')

# %% [markdown]
# ### Filtre

# %%
new_df = csv_clean2_df.where("IATA_CODE = 'LAX' or IATA_CODE == 'DFW'")
new_df.show()
# Out:
# +---------+--------------------+-----------------+-----+-------+--------+----------+
# |IATA_CODE|             AIRPORT|             CITY|STATE|COUNTRY|LATITUDE| LONGITUDE|
# +---------+--------------------+-----------------+-----+-------+--------+----------+
# |      DFW|Dallas/Fort Worth...|Dallas-Fort Worth|   TX|    USA|32.89595|  -97.0372|
# |      LAX|Los Angeles Inter...|      Los Angeles|   CA|    USA|33.94254|-118.40807|
# +---------+--------------------+-----------------+-----+-------+--------+----------+

# %% [markdown]
# ### Tri

# %%
new_df = csv_clean2_df.orderBy("IATA_CODE")
new_df = csv_clean2_df.orderBy("IATA_CODE", ascending=False)
new_df = csv_clean2_df.orderBy("STATE", "IATA_CODE", ascending=[False, False])
new_df.show(5)
# Out:
# +---------+--------------------+------------+-----+-------+--------+----------+
# |IATA_CODE|             AIRPORT|        CITY|STATE|COUNTRY|LATITUDE| LONGITUDE|
# +---------+--------------------+------------+-----+-------+--------+----------+
# |      RKS|Rock Springs-Swee...|Rock Springs|   WY|    USA|41.59422|-109.06519|
# |      LAR|Laramie Regional ...|     Laramie|   WY|    USA|41.31205|-105.67499|
# |      JAC|Jackson Hole Airport|     Jackson|   WY|    USA|43.60732|-110.73774|
# |      GCC|Gillette-Campbell...|    Gillette|   WY|    USA| 44.3489|-105.53936|
# |      CPR|Natrona County In...|      Casper|   WY|    USA|42.90836|-106.46447|
# +---------+--------------------+------------+-----+-------+--------+----------+
# only showing top 5 rows

# %% [markdown]
# ### Join

# %%
states = [
    ("TX", "Texas"),
    ("AK", "Alaska")
]

columns = ["STATE_CODE", "STATE_NAME"]
states_df = spark.createDataFrame(states, columns)

join_df = csv_clean2_df.join(states_df, [csv_clean2_df.STATE == states_df.STATE_CODE])
# join_df = csv_clean2_df.join(states_df, [csv_clean2_df.STATE == states_df.STATE_CODE], how="leftouter")
join_df.show(5)
# Out:
# +---------+--------------------+-------------+-----+-------+--------+----------+----------+----------+
# |IATA_CODE|             AIRPORT|         CITY|STATE|COUNTRY|LATITUDE| LONGITUDE|STATE_CODE|STATE_NAME|
# +---------+--------------------+-------------+-----+-------+--------+----------+----------+----------+
# |      TYR|Tyler Pounds Regi...|        Tyler|   TX|    USA|32.35414| -95.40239|        TX|     Texas|
# |      SPS|Wichita Falls Mun...|Wichita Falls|   TX|    USA| 33.9888| -98.49189|        TX|     Texas|
# |      SJT|San Angelo Region...|   San Angelo|   TX|    USA|31.35775|-100.49631|        TX|     Texas|
# |      SAT|San Antonio Inter...|  San Antonio|   TX|    USA|29.53369| -98.46978|        TX|     Texas|
# |      MFE|McAllen-Miller In...|      McAllen|   TX|    USA|26.17583| -98.23861|        TX|     Texas|
# +---------+--------------------+-------------+-----+-------+--------+----------+----------+----------+
# only showing top 5 rows

# %% [markdown]
# ### Aggregations

# %%
airports_by_state_df = csv_clean2_df.groupBy(F.col("STATE")).agg(F.count("STATE").alias("NB_AIRPORTS"))
airports_stats_df = csv_clean2_df.groupBy(F.col("STATE")).agg(F.count("STATE").alias("NB_AIRPORTS"), F.min("LATITUDE").alias("LAT_MIN"))
airports_stats_df.show(10)
airports_by_state_df.show(5)
# Out:
# +-----+-----------+--------+
# |STATE|NB_AIRPORTS| LAT_MIN|
# +-----+-----------+--------+
# |   SC|          4|32.89865|
# |   AZ|          4|32.11608|
# |   LA|          7|29.99339|
# |   MN|          8|43.90883|
# |   NJ|          3|39.45758|
# |   OR|          5|42.37423|
# |   VA|          7|36.89461|
# |   RI|          1|  41.724|
# |   WY|          6|41.31205|
# |   KY|          4|37.06083|
# +-----+-----------+--------+
# only showing top 10 rows
#
# +-----+-----------+
# |STATE|NB_AIRPORTS|
# +-----+-----------+
# |   SC|          4|
# |   AZ|          4|
# |   LA|          7|
# |   MN|          8|
# |   NJ|          3|
# +-----+-----------+
# only showing top 5 rows

# %% [markdown]
# ### Windowing

# %%
from pyspark.sql.window import Window
windowSpec = Window.partitionBy("STATE").orderBy("LATITUDE", "LONGITUDE")
window_df = csv_clean2_df.withColumn("rank", F.rank().over(windowSpec))
window_df.show()
# Out:
# +---------+--------------------+-----------+-----+-------+--------+----------+----+
# |IATA_CODE|             AIRPORT|       CITY|STATE|COUNTRY|LATITUDE| LONGITUDE|rank|
# +---------+--------------------+-----------+-----+-------+--------+----------+----+
# |      ADK|        Adak Airport|       Adak|   AK|    USA|51.87796|-176.64603|   1|
# |      KTN|Ketchikan Interna...|  Ketchikan|   AK|    USA|55.35557|-131.71375|   2|
# |      WRG|    Wrangell Airport|   Wrangell|   AK|    USA|56.48433|-132.36983|   3|
# |      PSG|Petersburg James ...| Petersburg|   AK|    USA|56.80165|-132.94528|   4|
# |      SIT|Sitka Rocky Gutie...|      Sitka|   AK|    USA|57.04714| -135.3616|   5|
# |      ADQ|      Kodiak Airport|     Kodiak|   AK|    USA|57.74997|-152.49387|   6|
# |      JNU|Juneau Internatio...|     Juneau|   AK|    USA|58.35496|-134.57628|   7|
# |      GST|    Gustavus Airport|   Gustavus|   AK|    USA|58.42438|-135.70738|   8|
# |      AKN| King Salmon Airport|King Salmon|   AK|    USA| 58.6768|-156.64922|   9|
# |      DLG|  Dillingham Airport| Dillingham|   AK|    USA|59.04541|-158.50334|  10|
# |      YAK|     Yakutat Airport|    Yakutat|   AK|    USA|59.50336|-139.66023|  11|
# |      CDV|Merle K. (Mudhole...|    Cordova|   AK|    USA|60.49183|-145.47765|  12|
# |      BET|      Bethel Airport|     Bethel|   AK|    USA|60.77978|  -161.838|  13|
# |      ANC|Ted Stevens Ancho...|  Anchorage|   AK|    USA|61.17432|-149.99619|  14|
# |      OME|        Nome Airport|       Nome|   AK|    USA| 64.5122|-165.44525|  15|
# |      FAI|Fairbanks Interna...|  Fairbanks|   AK|    USA|64.81368|-147.85966|  16|
# |      OTZ|Ralph Wien Memori...|   Kotzebue|   AK|    USA|66.88468|-162.59856|  17|
# |      SCC|Deadhorse Airport...|  Deadhorse|   AK|    USA|70.19476|-148.46516|  18|
# |      BRW|Wiley Post-Will R...|     Barrow|   AK|    USA|71.28545|  -156.766|  19|
# |      MOB|Mobile Regional A...|     Mobile|   AL|    USA|30.69142| -88.24283|   1|
# +---------+--------------------+-----------+-----+-------+--------+----------+----+
# only showing top 20 rows

# %% [markdown]
# ### Actions

# %%
window_df.take(3)
window_df.collect()
# Out:
# [Row(IATA_CODE='ADK', AIRPORT='Adak Airport', CITY='Adak', STATE='AK', COUNTRY='USA', LATITUDE=51.877960205078125, LONGITUDE=-176.64602661132812, rank=1),
#  Row(IATA_CODE='KTN', AIRPORT='Ketchikan International Airport', CITY='Ketchikan', STATE='AK', COUNTRY='USA', LATITUDE=55.35557174682617, LONGITUDE=-131.7137451171875, rank=2),
#  Row(IATA_CODE='WRG', AIRPORT='Wrangell Airport', CITY='Wrangell', STATE='AK', COUNTRY='USA', LATITUDE=56.48432922363281, LONGITUDE=-132.3698272705078, rank=3),
#  Row(IATA_CODE='PSG', AIRPORT='Petersburg James A. Johnson Airport', CITY='Petersburg', STATE='AK', COUNTRY='USA', LATITUDE=56.80165100097656, LONGITUDE=-132.94528198242188, rank=4),
#  Row(IATA_CODE='SIT', AIRPORT='Sitka Rocky Gutierrez Airport', CITY='Sitka', STATE='AK', COUNTRY='USA', LATITUDE=57.04713821411133, LONGITUDE=-135.36160278320312, rank=5),
#  Row(IATA_CODE='ADQ', AIRPORT='Kodiak Airport', CITY='Kodiak', STATE='AK', COUNTRY='USA', LATITUDE=57.749969482421875, LONGITUDE=-152.49386596679688, rank=6),
#  Row(IATA_CODE='JNU', AIRPORT='Juneau International Airport', CITY='Juneau', STATE='AK', COUNTRY='USA', LATITUDE=58.35496139526367, LONGITUDE=-134.57627868652344, rank=7),
#  Row(IATA_CODE='GST', AIRPORT='Gustavus Airport', CITY='Gustavus', STATE='AK', COUNTRY='USA', LATITUDE=58.424381256103516, LONGITUDE=-135.70738220214844, rank=8),
#  Row(IATA_CODE='AKN', AIRPORT='King Salmon Airport', CITY='King Salmon', STATE='AK', COUNTRY='USA', LATITUDE=58.67679977416992, LONGITUDE=-156.6492156982422, rank=9),
#  Row(IATA_CODE='DLG', AIRPORT='Dillingham Airport', CITY='Dillingham', STATE='AK', COUNTRY='USA', LATITUDE=59.04541015625, LONGITUDE=-158.5033416748047, rank=10),
#  Row(IATA_CODE='YAK', AIRPORT='Yakutat Airport', CITY='Yakutat', STATE='AK', COUNTRY='USA', LATITUDE=59.503360748291016, LONGITUDE=-139.6602325439453, rank=11),
#  Row(IATA_CODE='CDV', AIRPORT='Merle K. (Mudhole) Smith Airport', CITY='Cordova', STATE='AK', COUNTRY='USA', LATITUDE=60.49182891845703, LONGITUDE=-145.47764587402344, rank=12),
#  Row(IATA_CODE='BET', AIRPORT='Bethel Airport', CITY='Bethel', STATE='AK', COUNTRY='USA', LATITUDE=60.779781341552734, LONGITUDE=-161.83799743652344, rank=13),
#  Row(IATA_CODE='ANC', AIRPORT='Ted Stevens Anchorage International Airport', CITY='Anchorage', STATE='AK', COUNTRY='USA', LATITUDE=61.174320220947266, LONGITUDE=-149.99618530273438, rank=14),
#  Row(IATA_CODE='OME', AIRPORT='Nome Airport', CITY='Nome', STATE='AK', COUNTRY='USA', LATITUDE=64.51219940185547, LONGITUDE=-165.44525146484375, rank=15),
#  Row(IATA_CODE='FAI', AIRPORT='Fairbanks International Airport', CITY='Fairbanks', STATE='AK', COUNTRY='USA', LATITUDE=64.81368255615234, LONGITUDE=-147.8596649169922, rank=16),
#  Row(IATA_CODE='OTZ', AIRPORT='Ralph Wien Memorial Airport', CITY='Kotzebue', STATE='AK', COUNTRY='USA', LATITUDE=66.88468170166016, LONGITUDE=-162.5985565185547, rank=17),
#  Row(IATA_CODE='SCC', AIRPORT='Deadhorse Airport\xa0(Prudhoe Bay Airport)', CITY='Deadhorse', STATE='AK', COUNTRY='USA', LATITUDE=70.19476318359375, LONGITUDE=-148.4651641845703, rank=18),
#  Row(IATA_CODE='BRW', AIRPORT='Wiley Post-Will Rogers Memorial Airport', CITY='Barrow', STATE='AK', COUNTRY='USA', LATITUDE=71.28545379638672, LONGITUDE=-156.76600646972656, rank=19),
#  Row(IATA_CODE='MOB', AIRPORT='Mobile Regional Airport', CITY='Mobile', STATE='AL', COUNTRY='USA', LATITUDE=30.69141960144043, LONGITUDE=-88.24282836914062, rank=1),
#  Row(IATA_CODE='DHN', AIRPORT='Dothan Regional Airport', CITY='Dothan', STATE='AL', COUNTRY='USA', LATITUDE=31.321340560913086, LONGITUDE=-85.44963073730469, rank=2),
#  Row(IATA_CODE='MGM', AIRPORT='Montgomery Regional Airport', CITY='Montgomery', STATE='AL', COUNTRY='USA', LATITUDE=32.30064010620117, LONGITUDE=-86.39398193359375, rank=3),
#  Row(IATA_CODE='BHM', AIRPORT='Birmingham-Shuttlesworth International Airport', CITY='Birmingham', STATE='AL', COUNTRY='USA', LATITUDE=33.56293869018555, LONGITUDE=-86.75354766845703, rank=4),
#  Row(IATA_CODE='HSV', AIRPORT='Huntsville International Airport', CITY='Huntsville', STATE='AL', COUNTRY='USA', LATITUDE=34.64044952392578, LONGITUDE=-86.77310943603516, rank=5),
#  Row(IATA_CODE='TXK', AIRPORT='Texarkana Regional Airport\xa0(Webb Field)', CITY='Texarkana', STATE='AR', COUNTRY='USA', LATITUDE=33.45370864868164, LONGITUDE=-93.99102020263672, rank=1),
#  Row(IATA_CODE='LIT', AIRPORT='Bill and Hillary Clinton National Airport\xa0(Adams Field)', CITY='Little Rock', STATE='AR', COUNTRY='USA', LATITUDE=34.729400634765625, LONGITUDE=-92.22425079345703, rank=2),
#  Row(IATA_CODE='FSM', AIRPORT='Fort Smith Regional Airport', CITY='Fort Smith', STATE='AR', COUNTRY='USA', LATITUDE=35.33658981323242, LONGITUDE=-94.36743927001953, rank=3),
#  Row(IATA_CODE='XNA', AIRPORT='Northwest Arkansas Regional Airport', CITY='Fayetteville/Springdale/Rogers', STATE='AR', COUNTRY='USA', LATITUDE=36.2818717956543, LONGITUDE=-94.30680847167969, rank=4),
#  Row(IATA_CODE='PPG', AIRPORT='Pago Pago International Airport (Tafuna Airport)', CITY='Pago Pago', STATE='AS', COUNTRY='USA', LATITUDE=14.33102035522461, LONGITUDE=-170.7105255126953, rank=1),
#  Row(IATA_CODE='TUS', AIRPORT='Tucson International Airport', CITY='Tucson', STATE='AZ', COUNTRY='USA', LATITUDE=32.11608123779297, LONGITUDE=-110.94103240966797, rank=1),
#  Row(IATA_CODE='YUM', AIRPORT='Yuma International Airport', CITY='Yuma', STATE='AZ', COUNTRY='USA', LATITUDE=32.65658187866211, LONGITUDE=-114.60597229003906, rank=2),
#  Row(IATA_CODE='PHX', AIRPORT='Phoenix Sky Harbor International Airport', CITY='Phoenix', STATE='AZ', COUNTRY='USA', LATITUDE=33.43416976928711, LONGITUDE=-112.008056640625, rank=3),
#  Row(IATA_CODE='FLG', AIRPORT='Flagstaff Pulliam Airport', CITY='Flagstaff', STATE='AZ', COUNTRY='USA', LATITUDE=35.138450622558594, LONGITUDE=-111.67121887207031, rank=4),
#  Row(IATA_CODE='SAN', AIRPORT='San Diego International Airport\xa0(Lindbergh Field)', CITY='San Diego', STATE='CA', COUNTRY='USA', LATITUDE=32.733558654785156, LONGITUDE=-117.18965911865234, rank=1),
#  Row(IATA_CODE='CLD', AIRPORT='McClellan-Palomar Airport', CITY='San Diego', STATE='CA', COUNTRY='USA', LATITUDE=33.12723159790039, LONGITUDE=-117.27873229980469, rank=2),
#  Row(IATA_CODE='SNA', AIRPORT='John Wayne Airport\xa0(Orange County Airport)', CITY='Santa Ana', STATE='CA', COUNTRY='USA', LATITUDE=33.6756591796875, LONGITUDE=-117.86821746826172, rank=3),
#  Row(IATA_CODE='LGB', AIRPORT='Long Beach Airport\xa0(Daugherty Field)', CITY='Long Beach', STATE='CA', COUNTRY='USA', LATITUDE=33.817718505859375, LONGITUDE=-118.151611328125, rank=4),
#  Row(IATA_CODE='PSP', AIRPORT='Palm Springs International Airport', CITY='Palm Springs', STATE='CA', COUNTRY='USA', LATITUDE=33.829219818115234, LONGITUDE=-116.5062484741211, rank=5),
#  Row(IATA_CODE='LAX', AIRPORT='Los Angeles International Airport', CITY='Los Angeles', STATE='CA', COUNTRY='USA', LATITUDE=33.94253921508789, LONGITUDE=-118.40807342529297, rank=6),
#  Row(IATA_CODE='ONT', AIRPORT='Ontario International Airport', CITY='Ontario', STATE='CA', COUNTRY='USA', LATITUDE=34.055999755859375, LONGITUDE=-117.60118865966797, rank=7),
#  Row(IATA_CODE='BUR', AIRPORT='Bob Hope Airport\xa0(Hollywood Burbank Airport)', CITY='Burbank', STATE='CA', COUNTRY='USA', LATITUDE=34.200618743896484, LONGITUDE=-118.3584976196289, rank=8),
#  Row(IATA_CODE='SBA', AIRPORT='Santa Barbara Municipal Airport\xa0(Santa Barbara Airport)', CITY='Santa Barbara', STATE='CA', COUNTRY='USA', LATITUDE=34.42620849609375, LONGITUDE=-119.84037017822266, rank=9),
#  Row(IATA_CODE='SMX', AIRPORT='Santa Maria Public Airport\xa0(Capt G. Allan Hancock Field)', CITY='Santa Maria', STATE='CA', COUNTRY='USA', LATITUDE=34.89925003051758, LONGITUDE=-120.45758056640625, rank=10),
#  Row(IATA_CODE='SBP', AIRPORT='San Luis Obispo County Regional Airport\xa0(McChesney Field)', CITY='San Luis Obispo', STATE='CA', COUNTRY='USA', LATITUDE=35.237060546875, LONGITUDE=-120.64238739013672, rank=11),
#  Row(IATA_CODE='BFL', AIRPORT='Meadows Field', CITY='Bakersfield', STATE='CA', COUNTRY='USA', LATITUDE=35.43360137939453, LONGITUDE=-119.05677032470703, rank=12),
#  Row(IATA_CODE='MRY', AIRPORT='Monterey Regional Airport\xa0(Monterey Peninsula Airport)', CITY='Monterey', STATE='CA', COUNTRY='USA', LATITUDE=36.586978912353516, LONGITUDE=-121.84294891357422, rank=13),
#  Row(IATA_CODE='FAT', AIRPORT='Fresno Yosemite International Airport', CITY='Fresno', STATE='CA', COUNTRY='USA', LATITUDE=36.77619171142578, LONGITUDE=-119.7181396484375, rank=14),
#  Row(IATA_CODE='SJC', AIRPORT='Norman Y. Mineta San José International Airport', CITY='San Jose', STATE='CA', COUNTRY='USA', LATITUDE=37.36185836791992, LONGITUDE=-121.92900848388672, rank=15),
#  Row(IATA_CODE='SFO', AIRPORT='San Francisco International Airport', CITY='San Francisco', STATE='CA', COUNTRY='USA', LATITUDE=37.61899948120117, LONGITUDE=-122.37483978271484, rank=16),
#  Row(IATA_CODE='MMH', AIRPORT='Mammoth Yosemite Airport', CITY='Mammoth Lakes', STATE='CA', COUNTRY='USA', LATITUDE=37.62405014038086, LONGITUDE=-118.8377685546875, rank=17),
#  Row(IATA_CODE='OAK', AIRPORT='Oakland International Airport', CITY='Oakland', STATE='CA', COUNTRY='USA', LATITUDE=37.721290588378906, LONGITUDE=-122.22071838378906, rank=18),
#  Row(IATA_CODE='SMF', AIRPORT='Sacramento International Airport', CITY='Sacramento', STATE='CA', COUNTRY='USA', LATITUDE=38.69541931152344, LONGITUDE=-121.59076690673828, rank=19),
#  Row(IATA_CODE='RDD', AIRPORT='Redding Municipal Airport', CITY='Redding', STATE='CA', COUNTRY='USA', LATITUDE=40.50897979736328, LONGITUDE=-122.29340362548828, rank=20),
#  Row(IATA_CODE='ACV', AIRPORT='Arcata Airport', CITY='Arcata/Eureka', STATE='CA', COUNTRY='USA', LATITUDE=40.978118896484375, LONGITUDE=-124.1086196899414, rank=21),
#  Row(IATA_CODE='CEC', AIRPORT='Del Norte County Airport\xa0(Jack McNamara Field)', CITY='Crescent City', STATE='CA', COUNTRY='USA', LATITUDE=41.78015899658203, LONGITUDE=-124.23652648925781, rank=22),
#  Row(IATA_CODE='DRO', AIRPORT='Durango-La Plata County Airport', CITY='Durango', STATE='CO', COUNTRY='USA', LATITUDE=37.151519775390625, LONGITUDE=-107.75376892089844, rank=1),
#  Row(IATA_CODE='PUB', AIRPORT='Pueblo Memorial Airport', CITY='Pueblo', STATE='CO', COUNTRY='USA', LATITUDE=38.28908920288086, LONGITUDE=-104.49656677246094, rank=2),
#  Row(IATA_CODE='MTJ', AIRPORT='Montrose Regional Airport', CITY='Montrose', STATE='CO', COUNTRY='USA', LATITUDE=38.50886917114258, LONGITUDE=-107.89382934570312, rank=3),
#  Row(IATA_CODE='GUC', AIRPORT='Gunnison-Crested Butte Regional Airport', CITY='Gunnison', STATE='CO', COUNTRY='USA', LATITUDE=38.533958435058594, LONGITUDE=-106.93318176269531, rank=4),
#  Row(IATA_CODE='COS', AIRPORT='City of Colorado Springs Municipal Airport', CITY='Colorado Springs', STATE='CO', COUNTRY='USA', LATITUDE=38.805809020996094, LONGITUDE=-104.70024871826172, rank=5),
#  Row(IATA_CODE='GJT', AIRPORT='Grand Junction Regional Airport\xa0(Walker Field)', CITY='Grand Junction', STATE='CO', COUNTRY='USA', LATITUDE=39.12240982055664, LONGITUDE=-108.5267333984375, rank=6),
#  Row(IATA_CODE='ASE', AIRPORT='Aspen-Pitkin County Airport', CITY='Aspen', STATE='CO', COUNTRY='USA', LATITUDE=39.22315979003906, LONGITUDE=-106.86885070800781, rank=7),
#  Row(IATA_CODE='EGE', AIRPORT='Eagle County Regional Airport', CITY='Eagle', STATE='CO', COUNTRY='USA', LATITUDE=39.64257049560547, LONGITUDE=-106.9177017211914, rank=8),
#  Row(IATA_CODE='DEN', AIRPORT='Denver International Airport', CITY='Denver', STATE='CO', COUNTRY='USA', LATITUDE=39.8584098815918, LONGITUDE=-104.66699981689453, rank=9),
#  Row(IATA_CODE='HDN', AIRPORT='Yampa Valley Airport\xa0(Yampa Valley Regional)', CITY='Hayden', STATE='CO', COUNTRY='USA', LATITUDE=40.481178283691406, LONGITUDE=-107.21765899658203, rank=10),
#  Row(IATA_CODE='BDL', AIRPORT='Bradley International Airport', CITY='Windsor Locks', STATE='CT', COUNTRY='USA', LATITUDE=41.93886947631836, LONGITUDE=-72.6832275390625, rank=1),
#  Row(IATA_CODE='ILG', AIRPORT='Wilmington Airport', CITY='Wilmington', STATE='DE', COUNTRY='USA', LATITUDE=39.67871856689453, LONGITUDE=-75.60652923583984, rank=1),
#  Row(IATA_CODE='ECP', AIRPORT='Northwest Florida Beaches International Airport', CITY='Panama City', STATE='FL', COUNTRY='USA', LATITUDE=None, LONGITUDE=None, rank=1),
#  Row(IATA_CODE='UST', AIRPORT='Northeast Florida Regional Airport\xa0(St. Augustine Airport)', CITY='St. Augustine', STATE='FL', COUNTRY='USA', LATITUDE=None, LONGITUDE=None, rank=1),
#  Row(IATA_CODE='EYW', AIRPORT='Key West International Airport', CITY='Key West', STATE='FL', COUNTRY='USA', LATITUDE=24.556110382080078, LONGITUDE=-81.75955963134766, rank=3),
#  Row(IATA_CODE='MIA', AIRPORT='Miami International Airport', CITY='Miami', STATE='FL', COUNTRY='USA', LATITUDE=25.793249130249023, LONGITUDE=-80.29055786132812, rank=4),
#  Row(IATA_CODE='FLL', AIRPORT='Fort Lauderdale-Hollywood International Airport', CITY='Ft. Lauderdale', STATE='FL', COUNTRY='USA', LATITUDE=26.072580337524414, LONGITUDE=-80.15274810791016, rank=5),
#  Row(IATA_CODE='RSW', AIRPORT='Southwest Florida International Airport', CITY='Ft. Myers', STATE='FL', COUNTRY='USA', LATITUDE=26.536169052124023, LONGITUDE=-81.75517272949219, rank=6),
#  Row(IATA_CODE='PBI', AIRPORT='Palm Beach International Airport', CITY='West Palm Beach', STATE='FL', COUNTRY='USA', LATITUDE=26.68316078186035, LONGITUDE=-80.09558868408203, rank=7),
#  Row(IATA_CODE='SRQ', AIRPORT='Sarasota-Bradenton International Airport', CITY='Sarasota', STATE='FL', COUNTRY='USA', LATITUDE=27.39533042907715, LONGITUDE=-82.55410766601562, rank=8),
#  Row(IATA_CODE='TPA', AIRPORT='Tampa International Airport', CITY='Tampa', STATE='FL', COUNTRY='USA', LATITUDE=27.9754695892334, LONGITUDE=-82.53324890136719, rank=9),
#  Row(IATA_CODE='MLB', AIRPORT='Melbourne International Airport', CITY='Melbourne', STATE='FL', COUNTRY='USA', LATITUDE=28.102750778198242, LONGITUDE=-80.64581298828125, rank=10),
#  Row(IATA_CODE='MCO', AIRPORT='Orlando International Airport', CITY='Orlando', STATE='FL', COUNTRY='USA', LATITUDE=28.428890228271484, LONGITUDE=-81.31603240966797, rank=11),
#  Row(IATA_CODE='DAB', AIRPORT='Daytona Beach International Airport', CITY='Daytona Beach', STATE='FL', COUNTRY='USA', LATITUDE=29.179920196533203, LONGITUDE=-81.05805969238281, rank=12),
#  Row(IATA_CODE='GNV', AIRPORT='Gainesville Regional Airport', CITY='Gainesville', STATE='FL', COUNTRY='USA', LATITUDE=29.690059661865234, LONGITUDE=-82.27178192138672, rank=13),
#  Row(IATA_CODE='TLH', AIRPORT='Tallahassee International Airport', CITY='Tallahassee', STATE='FL', COUNTRY='USA', LATITUDE=30.396530151367188, LONGITUDE=-84.35032653808594, rank=14),
#  Row(IATA_CODE='PNS', AIRPORT='Pensacola International Airport\xa0(Pensacola Gulf Coast Regional Airport)', CITY='Pensacola', STATE='FL', COUNTRY='USA', LATITUDE=30.473310470581055, LONGITUDE=-87.18743896484375, rank=15),
#  Row(IATA_CODE='VPS', AIRPORT='Destin-Fort Walton Beach Airport/Eglin AFB', CITY='Valparaiso', STATE='FL', COUNTRY='USA', LATITUDE=30.48324966430664, LONGITUDE=-86.52539825439453, rank=16),
#  Row(IATA_CODE='JAX', AIRPORT='Jacksonville International Airport', CITY='Jacksonville', STATE='FL', COUNTRY='USA', LATITUDE=30.494060516357422, LONGITUDE=-81.68785858154297, rank=17),
#  Row(IATA_CODE='VLD', AIRPORT='Valdosta Regional Airport', CITY='Valdosta', STATE='GA', COUNTRY='USA', LATITUDE=30.782499313354492, LONGITUDE=-83.27671813964844, rank=1),
#  Row(IATA_CODE='BQK', AIRPORT='Brunswick Golden Isles Airport', CITY='Brunswick', STATE='GA', COUNTRY='USA', LATITUDE=31.259029388427734, LONGITUDE=-81.46630859375, rank=2),
#  Row(IATA_CODE='ABY', AIRPORT='Southwest Georgia Regional Airport', CITY='Albany', STATE='GA', COUNTRY='USA', LATITUDE=31.535520553588867, LONGITUDE=-84.19447326660156, rank=3),
#  Row(IATA_CODE='SAV', AIRPORT='Savannah/Hilton Head International Airport', CITY='Savannah', STATE='GA', COUNTRY='USA', LATITUDE=32.12757873535156, LONGITUDE=-81.20214080810547, rank=4),
#  Row(IATA_CODE='CSG', AIRPORT='Columbus Metropolitan Airport', CITY='Columbus', STATE='GA', COUNTRY='USA', LATITUDE=32.51633071899414, LONGITUDE=-84.93885803222656, rank=5),
#  Row(IATA_CODE='AGS', AIRPORT='Augusta Regional Airport\xa0(Bush Field)', CITY='Augusta', STATE='GA', COUNTRY='USA', LATITUDE=33.36996078491211, LONGITUDE=-81.9645004272461, rank=6),
#  Row(IATA_CODE='ATL', AIRPORT='Hartsfield-Jackson Atlanta International Airport', CITY='Atlanta', STATE='GA', COUNTRY='USA', LATITUDE=33.64044189453125, LONGITUDE=-84.42694091796875, rank=7),
#  Row(IATA_CODE='GUM', AIRPORT='Guam International Airport', CITY='Agana', STATE='GU', COUNTRY='USA', LATITUDE=13.483449935913086, LONGITUDE=-144.7959747314453, rank=1),
#  Row(IATA_CODE='ITO', AIRPORT='Hilo International Airport', CITY='Hilo', STATE='HI', COUNTRY='USA', LATITUDE=19.720260620117188, LONGITUDE=-155.04847717285156, rank=1),
#  Row(IATA_CODE='KOA', AIRPORT='Kona International Airport at Keahole', CITY='Kailua/Kona', STATE='HI', COUNTRY='USA', LATITUDE=19.73876953125, LONGITUDE=-156.04562377929688, rank=2),
#  Row(IATA_CODE='OGG', AIRPORT='Kahului Airport', CITY='Kahului', STATE='HI', COUNTRY='USA', LATITUDE=20.898649215698242, LONGITUDE=-156.4304656982422, rank=3),
#  Row(IATA_CODE='HNL', AIRPORT='Honolulu International Airport', CITY='Honolulu', STATE='HI', COUNTRY='USA', LATITUDE=21.318689346313477, LONGITUDE=-157.9224090576172, rank=4),
#  Row(IATA_CODE='LIH', AIRPORT='Lihue Airport', CITY='Lihue', STATE='HI', COUNTRY='USA', LATITUDE=21.975980758666992, LONGITUDE=-159.33895874023438, rank=5),
#  Row(IATA_CODE='DSM', AIRPORT='Des Moines International Airport', CITY='Des Moines', STATE='IA', COUNTRY='USA', LATITUDE=41.53493118286133, LONGITUDE=-93.66068267822266, rank=1),
#  Row(IATA_CODE='CID', AIRPORT='The Eastern Iowa Airport', CITY='Cedar Rapids', STATE='IA', COUNTRY='USA', LATITUDE=41.88459014892578, LONGITUDE=-91.71086883544922, rank=2),
#  Row(IATA_CODE='SUX', AIRPORT='Sioux Gateway Airport', CITY='Sioux City', STATE='IA', COUNTRY='USA', LATITUDE=42.4025993347168, LONGITUDE=-96.38436889648438, rank=3),
#  Row(IATA_CODE='DBQ', AIRPORT='Dubuque Regional Airport', CITY='Dubuque', STATE='IA', COUNTRY='USA', LATITUDE=42.40296173095703, LONGITUDE=-90.70916748046875, rank=4),
#  Row(IATA_CODE='ALO', AIRPORT='Waterloo Regional Airport', CITY='Waterloo', STATE='IA', COUNTRY='USA', LATITUDE=42.55707931518555, LONGITUDE=-92.40033721923828, rank=5),
#  Row(IATA_CODE='TWF', AIRPORT='Magic Valley Regional Airport\xa0(Joslin Field)', CITY='Twin Falls', STATE='ID', COUNTRY='USA', LATITUDE=42.4818000793457, LONGITUDE=-114.48773956298828, rank=1),
#  Row(IATA_CODE='PIH', AIRPORT='Pocatello Regional Airport', CITY='Pocatello', STATE='ID', COUNTRY='USA', LATITUDE=42.91130828857422, LONGITUDE=-112.59586334228516, rank=2),
#  Row(IATA_CODE='SUN', AIRPORT='Friedman Memorial Airport', CITY='Hailey', STATE='ID', COUNTRY='USA', LATITUDE=43.50484085083008, LONGITUDE=-114.29659271240234, rank=3),
#  Row(IATA_CODE='IDA', AIRPORT='Idaho Falls Regional Airport', CITY='Idaho Falls', STATE='ID', COUNTRY='USA', LATITUDE=43.51456069946289, LONGITUDE=-112.0701675415039, rank=4),
#  Row(IATA_CODE='BOI', AIRPORT='Boise Airport\xa0(Boise Air Terminal)', CITY='Boise', STATE='ID', COUNTRY='USA', LATITUDE=43.5644416809082, LONGITUDE=-116.2227783203125, rank=5),
#  Row(IATA_CODE='LWS', AIRPORT='Lewiston-Nez Perce County Airport', CITY='Lewiston', STATE='ID', COUNTRY='USA', LATITUDE=46.3745002746582, LONGITUDE=-117.01538848876953, rank=6),
#  Row(IATA_CODE='SPI', AIRPORT='Abraham Lincoln Capital Airport', CITY='Springfield', STATE='IL', COUNTRY='USA', LATITUDE=39.84394836425781, LONGITUDE=-89.67761993408203, rank=1),
#  Row(IATA_CODE='CMI', AIRPORT='University of Illinois - Willard Airport', CITY='Champaign/Urbana', STATE='IL', COUNTRY='USA', LATITUDE=40.039249420166016, LONGITUDE=-88.27806091308594, rank=2),
#  Row(IATA_CODE='BMI', AIRPORT='Central Illinois Regional Airport at Bloomington-Normal', CITY='Bloomington', STATE='IL', COUNTRY='USA', LATITUDE=40.477989196777344, LONGITUDE=-88.91594696044922, rank=3),
#  Row(IATA_CODE='PIA', AIRPORT='General Wayne A. Downing Peoria International Airport', CITY='Peoria', STATE='IL', COUNTRY='USA', LATITUDE=40.664241790771484, LONGITUDE=-89.69331359863281, rank=4),
#  Row(IATA_CODE='MLI', AIRPORT='Quad City International Airport', CITY='Moline', STATE='IL', COUNTRY='USA', LATITUDE=41.44852828979492, LONGITUDE=-90.50753784179688, rank=5),
#  Row(IATA_CODE='MDW', AIRPORT='Chicago Midway International Airport', CITY='Chicago', STATE='IL', COUNTRY='USA', LATITUDE=41.785980224609375, LONGITUDE=-87.7524185180664, rank=6),
#  Row(IATA_CODE='ORD', AIRPORT="Chicago O'Hare International Airport", CITY='Chicago', STATE='IL', COUNTRY='USA', LATITUDE=41.97959899902344, LONGITUDE=-87.90445709228516, rank=7),
#  Row(IATA_CODE='EVV', AIRPORT='Evansville Regional Airport', CITY='Evansville', STATE='IN', COUNTRY='USA', LATITUDE=38.03799057006836, LONGITUDE=-87.53063201904297, rank=1),
#  Row(IATA_CODE='IND', AIRPORT='Indianapolis International Airport', CITY='Indianapolis', STATE='IN', COUNTRY='USA', LATITUDE=39.71733093261719, LONGITUDE=-86.29438018798828, rank=2),
#  Row(IATA_CODE='FWA', AIRPORT='Fort Wayne International Airport', CITY='Fort Wayne', STATE='IN', COUNTRY='USA', LATITUDE=40.97846984863281, LONGITUDE=-85.19515228271484, rank=3),
#  Row(IATA_CODE='SBN', AIRPORT='South Bend International Airport\xa0(South Bend Regional)', CITY='South Bend', STATE='IN', COUNTRY='USA', LATITUDE=41.70895004272461, LONGITUDE=-86.31846618652344, rank=4),
#  Row(IATA_CODE='ICT', AIRPORT='Wichita Dwight D. Eisenhower National Airport\xa0(Wichita Mid-Continent Airport)', CITY='Wichita', STATE='KS', COUNTRY='USA', LATITUDE=37.649959564208984, LONGITUDE=-97.43305206298828, rank=1),
#  Row(IATA_CODE='GCK', AIRPORT='Garden City Regional Airport', CITY='Garden City', STATE='KS', COUNTRY='USA', LATITUDE=37.927520751953125, LONGITUDE=-100.72441101074219, rank=2),
#  Row(IATA_CODE='HYS', AIRPORT='Hays Regional Airport', CITY='Hays', STATE='KS', COUNTRY='USA', LATITUDE=38.844940185546875, LONGITUDE=-99.27403259277344, rank=3),
#  Row(IATA_CODE='MHK', AIRPORT='Manhattan Regional Airport', CITY='Manhattan', STATE='KS', COUNTRY='USA', LATITUDE=39.140968322753906, LONGITUDE=-96.67082977294922, rank=4),
#  Row(IATA_CODE='PAH', AIRPORT='Barkley Regional Airport', CITY='Paducah', STATE='KY', COUNTRY='USA', LATITUDE=37.060829162597656, LONGITUDE=-88.77375030517578, rank=1),
#  Row(IATA_CODE='LEX', AIRPORT='Blue Grass Airport', CITY='Lexington', STATE='KY', COUNTRY='USA', LATITUDE=38.03696823120117, LONGITUDE=-84.60539245605469, rank=2),
#  Row(IATA_CODE='SDF', AIRPORT='Louisville International Airport\xa0(Standiford Field)', CITY='Louisville', STATE='KY', COUNTRY='USA', LATITUDE=38.17438888549805, LONGITUDE=-85.73600006103516, rank=3),
#  Row(IATA_CODE='CVG', AIRPORT='Cincinnati/Northern Kentucky International Airport', CITY='Covington', STATE='KY', COUNTRY='USA', LATITUDE=39.046138763427734, LONGITUDE=-84.66217041015625, rank=4),
#  Row(IATA_CODE='MSY', AIRPORT='Louis Armstrong New Orleans International Airport', CITY='New Orleans', STATE='LA', COUNTRY='USA', LATITUDE=29.993389129638672, LONGITUDE=-90.2580337524414, rank=1),
#  Row(IATA_CODE='LCH', AIRPORT='Lake Charles Regional Airport', CITY='Lake Charles', STATE='LA', COUNTRY='USA', LATITUDE=30.126100540161133, LONGITUDE=-93.22339630126953, rank=2),
#  Row(IATA_CODE='LFT', AIRPORT='Lafayette Regional Airport', CITY='Lafayette', STATE='LA', COUNTRY='USA', LATITUDE=30.205280303955078, LONGITUDE=-91.98766326904297, rank=3),
#  Row(IATA_CODE='BTR', AIRPORT='Baton Rouge Metropolitan Airport', CITY='Baton Rouge', STATE='LA', COUNTRY='USA', LATITUDE=30.533159255981445, LONGITUDE=-91.14962768554688, rank=4),
#  Row(IATA_CODE='AEX', AIRPORT='Alexandria International Airport', CITY='Alexandria', STATE='LA', COUNTRY='USA', LATITUDE=31.327369689941406, LONGITUDE=-92.5485610961914, rank=5),
#  Row(IATA_CODE='SHV', AIRPORT='Shreveport Regional Airport', CITY='Shreveport', STATE='LA', COUNTRY='USA', LATITUDE=32.44662857055664, LONGITUDE=-93.82559967041016, rank=6),
#  Row(IATA_CODE='MLU', AIRPORT='Monroe Regional Airport', CITY='Monroe', STATE='LA', COUNTRY='USA', LATITUDE=32.51087188720703, LONGITUDE=-92.03768920898438, rank=7),
#  Row(IATA_CODE='ACK', AIRPORT='Nantucket Memorial Airport', CITY='Nantucket', STATE='MA', COUNTRY='USA', LATITUDE=41.2530517578125, LONGITUDE=-70.0601806640625, rank=1),
#  Row(IATA_CODE='MVY', AIRPORT="Martha's Vineyard Airport", CITY='Marthas Vineyard', STATE='MA', COUNTRY='USA', LATITUDE=41.393028259277344, LONGITUDE=-70.61432647705078, rank=2),
#  Row(IATA_CODE='HYA', AIRPORT='Barnstable Municipal Airport', CITY='Hyannis', STATE='MA', COUNTRY='USA', LATITUDE=41.66933822631836, LONGITUDE=-70.28035736083984, rank=3),
#  Row(IATA_CODE='ORH', AIRPORT='Worcester Regional Airport', CITY='Worcester', STATE='MA', COUNTRY='USA', LATITUDE=42.26734161376953, LONGITUDE=-71.8757095336914, rank=4),
#  Row(IATA_CODE='BOS', AIRPORT='Gen. Edward Lawrence Logan International Airport', CITY='Boston', STATE='MA', COUNTRY='USA', LATITUDE=42.364349365234375, LONGITUDE=-71.00518035888672, rank=5),
#  Row(IATA_CODE='BWI', AIRPORT='Baltimore-Washington International Airport', CITY='Baltimore', STATE='MD', COUNTRY='USA', LATITUDE=39.17539978027344, LONGITUDE=-76.66819763183594, rank=1),
#  Row(IATA_CODE='PWM', AIRPORT='Portland International Jetport', CITY='Portland', STATE='ME', COUNTRY='USA', LATITUDE=43.64617156982422, LONGITUDE=-70.30874633789062, rank=1),
#  Row(IATA_CODE='BGR', AIRPORT='Bangor International Airport', CITY='Bangor', STATE='ME', COUNTRY='USA', LATITUDE=44.80744171142578, LONGITUDE=-68.82814025878906, rank=2),
#  Row(IATA_CODE='DTW', AIRPORT='Detroit Metropolitan Airport', CITY='Detroit', STATE='MI', COUNTRY='USA', LATITUDE=42.212059020996094, LONGITUDE=-83.34883880615234, rank=1),
#  Row(IATA_CODE='AZO', AIRPORT='Kalamazoo/Battle Creek International Airport', CITY='Kalamazoo', STATE='MI', COUNTRY='USA', LATITUDE=42.23487854003906, LONGITUDE=-85.55206298828125, rank=2),
#  Row(IATA_CODE='LAN', AIRPORT='Capital Region International Airport\xa0( Lansing Capital City)', CITY='Lansing', STATE='MI', COUNTRY='USA', LATITUDE=42.77870178222656, LONGITUDE=-84.58735656738281, rank=3),
#  Row(IATA_CODE='GRR', AIRPORT='Gerald R. Ford International Airport', CITY='Grand Rapids', STATE='MI', COUNTRY='USA', LATITUDE=42.880821228027344, LONGITUDE=-85.52277374267578, rank=4),
#  Row(IATA_CODE='FNT', AIRPORT='Bishop International Airport', CITY='Flint', STATE='MI', COUNTRY='USA', LATITUDE=42.96549987792969, LONGITUDE=-83.74346160888672, rank=5),
#  Row(IATA_CODE='MKG', AIRPORT='Muskegon County Airport', CITY='Muskegon', STATE='MI', COUNTRY='USA', LATITUDE=43.169490814208984, LONGITUDE=-86.23822021484375, rank=6),
#  Row(IATA_CODE='MBS', AIRPORT='MBS International Airport', CITY='Saginaw', STATE='MI', COUNTRY='USA', LATITUDE=43.53290939331055, LONGITUDE=-84.07965087890625, rank=7),
#  Row(IATA_CODE='TVC', AIRPORT='Cherry Capital Airport', CITY='Traverse City', STATE='MI', COUNTRY='USA', LATITUDE=44.74143981933594, LONGITUDE=-85.58223724365234, rank=8),
#  Row(IATA_CODE='APN', AIRPORT='Alpena County Regional Airport', CITY='Alpena', STATE='MI', COUNTRY='USA', LATITUDE=45.07807159423828, LONGITUDE=-83.56028747558594, rank=9),
#  Row(IATA_CODE='PLN', AIRPORT='Pellston Regional Airport of Emmet County', CITY='Pellston', STATE='MI', COUNTRY='USA', LATITUDE=45.57093048095703, LONGITUDE=-84.79672241210938, rank=10),
#  Row(IATA_CODE='ESC', AIRPORT='Delta County Airport', CITY='Escanaba', STATE='MI', COUNTRY='USA', LATITUDE=45.72267150878906, LONGITUDE=-87.0937271118164, rank=11),
#  Row(IATA_CODE='IMT', AIRPORT='Ford Airport', CITY='Iron Mountain/Kingsford', STATE='MI', COUNTRY='USA', LATITUDE=45.81835174560547, LONGITUDE=-88.11454010009766, rank=12),
#  Row(IATA_CODE='CIU', AIRPORT='Chippewa County International Airport', CITY='Sault Ste. Marie', STATE='MI', COUNTRY='USA', LATITUDE=46.25075149536133, LONGITUDE=-84.4723892211914, rank=13),
#  Row(IATA_CODE='MQT', AIRPORT='Sawyer International Airport', CITY='Marquette', STATE='MI', COUNTRY='USA', LATITUDE=46.353641510009766, LONGITUDE=-87.3953628540039, rank=14),
#  Row(IATA_CODE='CMX', AIRPORT='Houghton County Memorial Airport', CITY='Hancock', STATE='MI', COUNTRY='USA', LATITUDE=47.168418884277344, LONGITUDE=-88.48905944824219, rank=15),
#  Row(IATA_CODE='RST', AIRPORT='Rochester International Airport', CITY='Rochester', STATE='MN', COUNTRY='USA', LATITUDE=43.90882873535156, LONGITUDE=-92.49799346923828, rank=1),
#  Row(IATA_CODE='MSP', AIRPORT='Minneapolis-Saint Paul International Airport', CITY='Minneapolis', STATE='MN', COUNTRY='USA', LATITUDE=44.880550384521484, LONGITUDE=-93.2169189453125, rank=2),
#  Row(IATA_CODE='STC', AIRPORT='St. Cloud Regional Airport', CITY='St Cloud', STATE='MN', COUNTRY='USA', LATITUDE=45.545318603515625, LONGITUDE=-94.05834197998047, rank=3),
#  Row(IATA_CODE='BRD', AIRPORT='Brainerd Lakes Regional Airport', CITY='Brainerd', STATE='MN', COUNTRY='USA', LATITUDE=46.39786148071289, LONGITUDE=-94.1372299194336, rank=4),
#  Row(IATA_CODE='DLH', AIRPORT='Duluth International Airport', CITY='Duluth', STATE='MN', COUNTRY='USA', LATITUDE=46.84209060668945, LONGITUDE=-92.19364929199219, rank=5),
#  Row(IATA_CODE='HIB', AIRPORT='Range Regional Airport\xa0(Chisholm-Hibbing Airport)', CITY='Hibbing', STATE='MN', COUNTRY='USA', LATITUDE=47.386600494384766, LONGITUDE=-92.8389892578125, rank=6),
#  Row(IATA_CODE='BJI', AIRPORT='Bemidji Regional Airport', CITY='Bemidji', STATE='MN', COUNTRY='USA', LATITUDE=47.50941848754883, LONGITUDE=-94.93372344970703, rank=7),
#  Row(IATA_CODE='INL', AIRPORT='Falls International Airport', CITY='International Falls', STATE='MN', COUNTRY='USA', LATITUDE=48.56618881225586, LONGITUDE=-93.40306854248047, rank=8),
#  Row(IATA_CODE='JLN', AIRPORT='Joplin Regional Airport', CITY='Joplin', STATE='MO', COUNTRY='USA', LATITUDE=37.15180969238281, LONGITUDE=-94.4982681274414, rank=1),
#  Row(IATA_CODE='SGF', AIRPORT='Springfield-Branson National Airport', CITY='Springfield', STATE='MO', COUNTRY='USA', LATITUDE=37.24433135986328, LONGITUDE=-93.3868637084961, rank=2),
#  Row(IATA_CODE='STL', AIRPORT='St. Louis International Airport at Lambert Field', CITY='St Louis', STATE='MO', COUNTRY='USA', LATITUDE=38.74768829345703, LONGITUDE=-90.35999298095703, rank=3),
#  Row(IATA_CODE='COU', AIRPORT='Columbia Regional Airport', CITY='Columbia', STATE='MO', COUNTRY='USA', LATITUDE=38.81808853149414, LONGITUDE=-92.2196273803711, rank=4),
#  Row(IATA_CODE='MCI', AIRPORT='Kansas City International Airport', CITY='Kansas City', STATE='MO', COUNTRY='USA', LATITUDE=39.297611236572266, LONGITUDE=-94.71391296386719, rank=5),
#  Row(IATA_CODE='GPT', AIRPORT='Gulfport-Biloxi International Airport', CITY='Gulfport-Biloxi', STATE='MS', COUNTRY='USA', LATITUDE=30.40727996826172, LONGITUDE=-89.0700912475586, rank=1),
#  Row(IATA_CODE='PIB', AIRPORT='Hattiesburg-Laurel Regional Airport', CITY='Hattiesburg-Laurel', STATE='MS', COUNTRY='USA', LATITUDE=31.46714973449707, LONGITUDE=-89.3370590209961, rank=2),
#  Row(IATA_CODE='JAN', AIRPORT='Jackson-Evers International Airport', CITY='Jackson', STATE='MS', COUNTRY='USA', LATITUDE=32.3111686706543, LONGITUDE=-90.07588958740234, rank=3),
#  Row(IATA_CODE='MEI', AIRPORT='Meridian Regional Airport', CITY='Meridian', STATE='MS', COUNTRY='USA', LATITUDE=32.3331298828125, LONGITUDE=-88.75121307373047, rank=4),
#  Row(IATA_CODE='GTR', AIRPORT='Golden Triangle Regional Airport', CITY='Columbus-Starkville-West Point', STATE='MS', COUNTRY='USA', LATITUDE=33.4503288269043, LONGITUDE=-88.59136962890625, rank=5),
#  Row(IATA_CODE='WYS', AIRPORT='Westerly State Airport', CITY='West Yellowstone', STATE='MT', COUNTRY='USA', LATITUDE=44.68840026855469, LONGITUDE=-111.11763763427734, rank=1),
#  Row(IATA_CODE='BZN', AIRPORT='Bozeman Yellowstone International Airport\xa0(Gallatin Field Airport)', CITY='Bozeman', STATE='MT', COUNTRY='USA', LATITUDE=45.77690124511719, LONGITUDE=-111.15300750732422, rank=2),
#  Row(IATA_CODE='BIL', AIRPORT='Billings Logan International Airport', CITY='Billings', STATE='MT', COUNTRY='USA', LATITUDE=45.80765914916992, LONGITUDE=-108.54286193847656, rank=3),
#  Row(IATA_CODE='BTM', AIRPORT='Bert Mooney Airport', CITY='Butte', STATE='MT', COUNTRY='USA', LATITUDE=45.95479965209961, LONGITUDE=-112.4974594116211, rank=4),
#  Row(IATA_CODE='HLN', AIRPORT='Helena Regional Airport', CITY='Helena', STATE='MT', COUNTRY='USA', LATITUDE=46.60681915283203, LONGITUDE=-111.98274993896484, rank=5),
#  Row(IATA_CODE='MSO', AIRPORT='Missoula International Airport', CITY='Missoula', STATE='MT', COUNTRY='USA', LATITUDE=46.91630935668945, LONGITUDE=-114.09056091308594, rank=6),
#  Row(IATA_CODE='GTF', AIRPORT='Great Falls International Airport', CITY='Great Falls', STATE='MT', COUNTRY='USA', LATITUDE=47.481998443603516, LONGITUDE=-111.37068939208984, rank=7),
#  Row(IATA_CODE='FCA', AIRPORT='Glacier Park International Airport', CITY='Kalispell', STATE='MT', COUNTRY='USA', LATITUDE=48.3114013671875, LONGITUDE=-114.25507354736328, rank=8),
#  Row(IATA_CODE='ILM', AIRPORT='Wilmington International Airport', CITY='Wilmington', STATE='NC', COUNTRY='USA', LATITUDE=34.27061080932617, LONGITUDE=-77.90255737304688, rank=1),
#  Row(IATA_CODE='OAJ', AIRPORT='Albert J. Ellis Airport', CITY='Jacksonville', STATE='NC', COUNTRY='USA', LATITUDE=34.829158782958984, LONGITUDE=-77.61213684082031, rank=2),
#  Row(IATA_CODE='FAY', AIRPORT='Fayetteville Regional Airport', CITY='Fayetteville', STATE='NC', COUNTRY='USA', LATITUDE=34.99147033691406, LONGITUDE=-78.87999725341797, rank=3),
#  Row(IATA_CODE='EWN', AIRPORT='Coastal Carolina Regional Airport\xa0(Craven County Regional)', CITY='New Bern', STATE='NC', COUNTRY='USA', LATITUDE=35.07297134399414, LONGITUDE=-77.04293823242188, rank=4),
#  Row(IATA_CODE='CLT', AIRPORT='Charlotte Douglas International Airport', CITY='Charlotte', STATE='NC', COUNTRY='USA', LATITUDE=35.21400833129883, LONGITUDE=-80.94313049316406, rank=5),
#  Row(IATA_CODE='AVL', AIRPORT='Asheville Regional Airport', CITY='Asheville', STATE='NC', COUNTRY='USA', LATITUDE=35.43619155883789, LONGITUDE=-82.54180908203125, rank=6),
#  Row(IATA_CODE='RDU', AIRPORT='Raleigh-Durham International Airport', CITY='Raleigh', STATE='NC', COUNTRY='USA', LATITUDE=35.87763977050781, LONGITUDE=-78.78746795654297, rank=7),
#  Row(IATA_CODE='GSO', AIRPORT='Piedmont Triad International Airport', CITY='Greensboro', STATE='NC', COUNTRY='USA', LATITUDE=36.09775161743164, LONGITUDE=-79.93730163574219, rank=8),
#  Row(IATA_CODE='BIS', AIRPORT='Bismarck Municipal Airport', CITY='Bismarck', STATE='ND', COUNTRY='USA', LATITUDE=46.77410888671875, LONGITUDE=-100.74671936035156, rank=1),
#  Row(IATA_CODE='DIK', AIRPORT='Dickinson Theodore Roosevelt Regional Airport', CITY='Dickinson', STATE='ND', COUNTRY='USA', LATITUDE=46.79738998413086, LONGITUDE=-102.80194854736328, rank=2),
#  Row(IATA_CODE='FAR', AIRPORT='Hector International Airport', CITY='Fargo', STATE='ND', COUNTRY='USA', LATITUDE=46.919349670410156, LONGITUDE=-96.81498718261719, rank=3),
#  Row(IATA_CODE='JMS', AIRPORT='Jamestown Regional Airport', CITY='Jamestown', STATE='ND', COUNTRY='USA', LATITUDE=46.92972183227539, LONGITUDE=-98.6781997680664, rank=4),
#  Row(IATA_CODE='GFK', AIRPORT='Grand Forks International Airport', CITY='Grand Forks', STATE='ND', COUNTRY='USA', LATITUDE=47.94926071166992, LONGITUDE=-97.17610931396484, rank=5),
#  Row(IATA_CODE='DVL', AIRPORT='Devils Lake Regional Airport', CITY='Devils Lake', STATE='ND', COUNTRY='USA', LATITUDE=48.11425018310547, LONGITUDE=-98.90878295898438, rank=6),
#  Row(IATA_CODE='ISN', AIRPORT='Sloulin Field International Airport', CITY='Williston', STATE='ND', COUNTRY='USA', LATITUDE=48.177940368652344, LONGITUDE=-103.64234924316406, rank=7),
#  Row(IATA_CODE='MOT', AIRPORT='Minot International Airport', CITY='Minot', STATE='ND', COUNTRY='USA', LATITUDE=48.25938034057617, LONGITUDE=-101.28032684326172, rank=8),
#  Row(IATA_CODE='LNK', AIRPORT='Lincoln Airport\xa0(Lincoln Municipal)', CITY='Lincoln', STATE='NE', COUNTRY='USA', LATITUDE=40.85097122192383, LONGITUDE=-96.75924682617188, rank=1),
#  Row(IATA_CODE='GRI', AIRPORT='Central Nebraska Regional Airport', CITY='Grand Island', STATE='NE', COUNTRY='USA', LATITUDE=40.96746826171875, LONGITUDE=-98.30860900878906, rank=2),
#  Row(IATA_CODE='OMA', AIRPORT='Eppley Airfield', CITY='Omaha', STATE='NE', COUNTRY='USA', LATITUDE=41.302520751953125, LONGITUDE=-95.89417266845703, rank=3),
#  Row(IATA_CODE='MHT', AIRPORT='Manchester-Boston Regional Airport', CITY='Manchester', STATE='NH', COUNTRY='USA', LATITUDE=42.93452072143555, LONGITUDE=-71.43705749511719, rank=1),
#  Row(IATA_CODE='ACY', AIRPORT='Atlantic City International Airport', CITY='Atlantic City', STATE='NJ', COUNTRY='USA', LATITUDE=39.45758056640625, LONGITUDE=-74.5771713256836, rank=1),
#  Row(IATA_CODE='TTN', AIRPORT='Trenton Mercer Airport', CITY='Trenton', STATE='NJ', COUNTRY='USA', LATITUDE=40.27669143676758, LONGITUDE=-74.81346893310547, rank=2),
#  Row(IATA_CODE='EWR', AIRPORT='Newark Liberty International Airport', CITY='Newark', STATE='NJ', COUNTRY='USA', LATITUDE=40.692501068115234, LONGITUDE=-74.16866302490234, rank=3),
#  Row(IATA_CODE='HOB', AIRPORT='Lea County Regional Airport', CITY='Hobbs', STATE='NM', COUNTRY='USA', LATITUDE=32.687530517578125, LONGITUDE=-103.21703338623047, rank=1),
#  Row(IATA_CODE='ROW', AIRPORT='Roswell International Air Center', CITY='Roswell', STATE='NM', COUNTRY='USA', LATITUDE=33.30155944824219, LONGITUDE=-104.53056335449219, rank=2),
#  Row(IATA_CODE='ABQ', AIRPORT='Albuquerque International Sunport', CITY='Albuquerque', STATE='NM', COUNTRY='USA', LATITUDE=35.040218353271484, LONGITUDE=-106.60919189453125, rank=3),
#  Row(IATA_CODE='SAF', AIRPORT='Santa Fe Municipal Airport', CITY='Santa Fe', STATE='NM', COUNTRY='USA', LATITUDE=35.61677932739258, LONGITUDE=-106.08814239501953, rank=4),
#  Row(IATA_CODE='LAS', AIRPORT='McCarran International Airport', CITY='Las Vegas', STATE='NV', COUNTRY='USA', LATITUDE=36.080360412597656, LONGITUDE=-115.15232849121094, rank=1),
#  Row(IATA_CODE='RNO', AIRPORT='Reno/Tahoe International Airport', CITY='Reno', STATE='NV', COUNTRY='USA', LATITUDE=39.49858093261719, LONGITUDE=-119.76805877685547, rank=2),
#  Row(IATA_CODE='EKO', AIRPORT='Elko Regional Airport', CITY='Elko', STATE='NV', COUNTRY='USA', LATITUDE=40.824928283691406, LONGITUDE=-115.79170227050781, rank=3),
#  Row(IATA_CODE='PBG', AIRPORT='Plattsburgh International Airport', CITY='Plattsburgh', STATE='NY', COUNTRY='USA', LATITUDE=None, LONGITUDE=None, rank=1),
#  Row(IATA_CODE='JFK', AIRPORT='John F. Kennedy International Airport\xa0(New York International Airport)', CITY='New York', STATE='NY', COUNTRY='USA', LATITUDE=40.63975143432617, LONGITUDE=-73.7789306640625, rank=2),
#  Row(IATA_CODE='LGA', AIRPORT='LaGuardia Airport (Marine Air Terminal)', CITY='New York', STATE='NY', COUNTRY='USA', LATITUDE=40.77724075317383, LONGITUDE=-73.87261199951172, rank=3),
#  Row(IATA_CODE='ISP', AIRPORT='Long Island MacArthur Airport', CITY='Islip', STATE='NY', COUNTRY='USA', LATITUDE=40.79523849487305, LONGITUDE=-73.10021209716797, rank=4),
#  Row(IATA_CODE='HPN', AIRPORT='Westchester County Airport', CITY='White Plains', STATE='NY', COUNTRY='USA', LATITUDE=41.066959381103516, LONGITUDE=-73.70757293701172, rank=5),
#  Row(IATA_CODE='SWF', AIRPORT='Stewart International Airport', CITY='Newburgh', STATE='NY', COUNTRY='USA', LATITUDE=41.50408935546875, LONGITUDE=-74.10484313964844, rank=6),
#  Row(IATA_CODE='ELM', AIRPORT='Elmira/Corning Regional Airport', CITY='Elmira', STATE='NY', COUNTRY='USA', LATITUDE=42.159908294677734, LONGITUDE=-76.89144134521484, rank=7),
#  Row(IATA_CODE='BGM', AIRPORT='Greater Binghamton Airport', CITY='Binghamton', STATE='NY', COUNTRY='USA', LATITUDE=42.20848083496094, LONGITUDE=-75.97960662841797, rank=8),
#  Row(IATA_CODE='ITH', AIRPORT='Ithaca Tompkins Regional Airport', CITY='Ithaca', STATE='NY', COUNTRY='USA', LATITUDE=42.491031646728516, LONGITUDE=-76.45844268798828, rank=9),
#  Row(IATA_CODE='ALB', AIRPORT='Albany International Airport', CITY='Albany', STATE='NY', COUNTRY='USA', LATITUDE=42.74811935424805, LONGITUDE=-73.802978515625, rank=10),
#  Row(IATA_CODE='BUF', AIRPORT='Buffalo Niagara International Airport', CITY='Buffalo', STATE='NY', COUNTRY='USA', LATITUDE=42.940521240234375, LONGITUDE=-78.73217010498047, rank=11),
#  Row(IATA_CODE='IAG', AIRPORT='Niagara Falls International Airport', CITY='Niagara Falls', STATE='NY', COUNTRY='USA', LATITUDE=43.107261657714844, LONGITUDE=-78.94538116455078, rank=12),
#  Row(IATA_CODE='SYR', AIRPORT='Syracuse Hancock International Airport', CITY='Syracuse', STATE='NY', COUNTRY='USA', LATITUDE=43.11119079589844, LONGITUDE=-76.10630798339844, rank=13),
#  Row(IATA_CODE='ROC', AIRPORT='Greater Rochester International Airport', CITY='Rochester', STATE='NY', COUNTRY='USA', LATITUDE=43.11886978149414, LONGITUDE=-77.67237854003906, rank=14),
#  Row(IATA_CODE='DAY', AIRPORT='James M. Cox Dayton International Airport', CITY='Dayton', STATE='OH', COUNTRY='USA', LATITUDE=39.902381896972656, LONGITUDE=-84.2193832397461, rank=1),
#  Row(IATA_CODE='CMH', AIRPORT='Port Columbus International Airport', CITY='Columbus', STATE='OH', COUNTRY='USA', LATITUDE=39.997989654541016, LONGITUDE=-82.89187622070312, rank=2),
#  Row(IATA_CODE='CAK', AIRPORT='Akron-Canton Regional Airport', CITY='Akron', STATE='OH', COUNTRY='USA', LATITUDE=40.91630935668945, LONGITUDE=-81.44246673583984, rank=3),
#  Row(IATA_CODE='CLE', AIRPORT='Cleveland Hopkins International Airport', CITY='Cleveland', STATE='OH', COUNTRY='USA', LATITUDE=41.410888671875, LONGITUDE=-81.84940338134766, rank=4),
#  Row(IATA_CODE='TOL', AIRPORT='Toledo Express Airport', CITY='Toledo', STATE='OH', COUNTRY='USA', LATITUDE=41.58681106567383, LONGITUDE=-83.80783081054688, rank=5),
#  Row(IATA_CODE='LAW', AIRPORT='Lawton-Fort Sill Regional Airport', CITY='Lawton', STATE='OK', COUNTRY='USA', LATITUDE=34.567710876464844, LONGITUDE=-98.41664123535156, rank=1),
#  Row(IATA_CODE='OKC', AIRPORT='Will Rogers World Airport', CITY='Oklahoma City', STATE='OK', COUNTRY='USA', LATITUDE=35.393089294433594, LONGITUDE=-97.6007308959961, rank=2),
#  Row(IATA_CODE='TUL', AIRPORT='Tulsa International Airport', CITY='Tulsa', STATE='OK', COUNTRY='USA', LATITUDE=36.19837188720703, LONGITUDE=-95.88823699951172, rank=3),
#  Row(IATA_CODE='MFR', AIRPORT='Rogue Valley International Airport', CITY='Medford', STATE='OR', COUNTRY='USA', LATITUDE=42.374229431152344, LONGITUDE=-122.87349700927734, rank=1),
#  Row(IATA_CODE='OTH', AIRPORT='Southwest Oregon Regional Airport\xa0(North Bend Municipal)', CITY='North Bend', STATE='OR', COUNTRY='USA', LATITUDE=43.41714096069336, LONGITUDE=-124.24603271484375, rank=2),
#  Row(IATA_CODE='EUG', AIRPORT='Eugene Airport\xa0(Mahlon Sweet Field)', CITY='Eugene', STATE='OR', COUNTRY='USA', LATITUDE=44.123260498046875, LONGITUDE=-123.21868896484375, rank=3),
#  Row(IATA_CODE='RDM', AIRPORT='Redmond Municipal Airport\xa0(Roberts Field)', CITY='Redmond', STATE='OR', COUNTRY='USA', LATITUDE=44.25407028198242, LONGITUDE=-121.14996337890625, rank=4),
#  Row(IATA_CODE='PDX', AIRPORT='Portland International Airport', CITY='Portland', STATE='OR', COUNTRY='USA', LATITUDE=45.58871841430664, LONGITUDE=-122.59750366210938, rank=5),
#  Row(IATA_CODE='PHL', AIRPORT='Philadelphia International Airport', CITY='Philadelphia', STATE='PA', COUNTRY='USA', LATITUDE=39.8719482421875, LONGITUDE=-75.24114227294922, rank=1),
#  Row(IATA_CODE='MDT', AIRPORT='Harrisburg International Airport', CITY='Harrisburg', STATE='PA', COUNTRY='USA', LATITUDE=40.19350051879883, LONGITUDE=-76.76339721679688, rank=2),
#  Row(IATA_CODE='LBE', AIRPORT='Arnold Palmer Regional Airport', CITY='Latrobe', STATE='PA', COUNTRY='USA', LATITUDE=40.27593994140625, LONGITUDE=-79.40480041503906, rank=3),
#  Row(IATA_CODE='PIT', AIRPORT='Pittsburgh International Airport', CITY='Pittsburgh', STATE='PA', COUNTRY='USA', LATITUDE=40.49147033691406, LONGITUDE=-80.23287200927734, rank=4),
#  Row(IATA_CODE='ABE', AIRPORT='Lehigh Valley International Airport', CITY='Allentown', STATE='PA', COUNTRY='USA', LATITUDE=40.65235900878906, LONGITUDE=-75.44039916992188, rank=5),
#  Row(IATA_CODE='SCE', AIRPORT='University Park Airport', CITY='State College', STATE='PA', COUNTRY='USA', LATITUDE=40.85121154785156, LONGITUDE=-77.84629821777344, rank=6),
#  Row(IATA_CODE='AVP', AIRPORT='Wilkes-Barre/Scranton International Airport', CITY='Wilkes-Barre/Scranton', STATE='PA', COUNTRY='USA', LATITUDE=41.33815002441406, LONGITUDE=-75.72427368164062, rank=7),
#  Row(IATA_CODE='ERI', AIRPORT='Erie International Airport', CITY='Erie', STATE='PA', COUNTRY='USA', LATITUDE=42.0820198059082, LONGITUDE=-80.17622375488281, rank=8),
#  Row(IATA_CODE='PSE', AIRPORT='Mercedita Airport', CITY='Ponce', STATE='PR', COUNTRY='USA', LATITUDE=18.00830078125, LONGITUDE=-66.5630111694336, rank=1),
#  Row(IATA_CODE='SJU', AIRPORT='Luis Muñoz Marín International Airport', CITY='San Juan', STATE='PR', COUNTRY='USA', LATITUDE=18.439420700073242, LONGITUDE=-66.0018310546875, rank=2),
#  Row(IATA_CODE='BQN', AIRPORT='Rafael Hernández Airport', CITY='Aguadilla', STATE='PR', COUNTRY='USA', LATITUDE=18.49485969543457, LONGITUDE=-67.12944030761719, rank=3),
#  Row(IATA_CODE='PVD', AIRPORT='Theodore Francis Green State Airport', CITY='Providence', STATE='RI', COUNTRY='USA', LATITUDE=41.7239990234375, LONGITUDE=-71.42822265625, rank=1),
#  Row(IATA_CODE='CHS', AIRPORT='Charleston International Airport/Charleston AFB', CITY='Charleston', STATE='SC', COUNTRY='USA', LATITUDE=32.898651123046875, LONGITUDE=-80.04051208496094, rank=1),
#  Row(IATA_CODE='MYR', AIRPORT='Myrtle Beach International Airport', CITY='Myrtle Beach', STATE='SC', COUNTRY='USA', LATITUDE=33.67974853515625, LONGITUDE=-78.92832946777344, rank=2),
#  Row(IATA_CODE='CAE', AIRPORT='Columbia Metropolitan Airport', CITY='Columbia', STATE='SC', COUNTRY='USA', LATITUDE=33.938838958740234, LONGITUDE=-81.11953735351562, rank=3),
#  Row(IATA_CODE='GSP', AIRPORT='Greenville-Spartanburg International Airport', CITY='Greer', STATE='SC', COUNTRY='USA', LATITUDE=34.89567184448242, LONGITUDE=-82.21885681152344, rank=4),
#  Row(IATA_CODE='FSD', AIRPORT='Sioux Falls Regional Airport', CITY='Sioux Falls', STATE='SD', COUNTRY='USA', LATITUDE=43.58134841918945, LONGITUDE=-96.74169921875, rank=1),
#  Row(IATA_CODE='RAP', AIRPORT='Rapid City Regional Airport', CITY='Rapid City', STATE='SD', COUNTRY='USA', LATITUDE=44.045318603515625, LONGITUDE=-103.057373046875, rank=2),
#  Row(IATA_CODE='ABR', AIRPORT='Aberdeen Regional Airport', CITY='Aberdeen', STATE='SD', COUNTRY='USA', LATITUDE=45.449058532714844, LONGITUDE=-98.42182922363281, rank=3),
#  Row(IATA_CODE='CHA', AIRPORT='Chattanooga Metropolitan Airport\xa0(Lovell Field)', CITY='Chattanooga', STATE='TN', COUNTRY='USA', LATITUDE=35.03527069091797, LONGITUDE=-85.20378875732422, rank=1),
#  Row(IATA_CODE='MEM', AIRPORT='Memphis International Airport', CITY='Memphis', STATE='TN', COUNTRY='USA', LATITUDE=35.04241943359375, LONGITUDE=-89.97666931152344, rank=2),
#  Row(IATA_CODE='TYS', AIRPORT='McGhee Tyson Airport', CITY='Knoxville', STATE='TN', COUNTRY='USA', LATITUDE=35.8124885559082, LONGITUDE=-83.99285888671875, rank=3),
#  Row(IATA_CODE='BNA', AIRPORT='Nashville International Airport', CITY='Nashville', STATE='TN', COUNTRY='USA', LATITUDE=36.124481201171875, LONGITUDE=-86.67817687988281, rank=4),
#  Row(IATA_CODE='TRI', AIRPORT='Tri-Cities Regional Airport', CITY='Bristol', STATE='TN', COUNTRY='USA', LATITUDE=36.4752082824707, LONGITUDE=-82.40741729736328, rank=5),
#  Row(IATA_CODE='BRO', AIRPORT='Brownsville/South Padre Island International Airport', CITY='Brownsville', STATE='TX', COUNTRY='USA', LATITUDE=25.906829833984375, LONGITUDE=-97.42585754394531, rank=1),
#  Row(IATA_CODE='MFE', AIRPORT='McAllen-Miller International Airport\xa0(McAllen Miller International)', CITY='McAllen', STATE='TX', COUNTRY='USA', LATITUDE=26.175830841064453, LONGITUDE=-98.23860931396484, rank=2),
#  Row(IATA_CODE='HRL', AIRPORT='Valley International Airport', CITY='Harlingen', STATE='TX', COUNTRY='USA', LATITUDE=26.2285099029541, LONGITUDE=-97.65438842773438, rank=3),
#  Row(IATA_CODE='LRD', AIRPORT='Laredo International Airport', CITY='Laredo', STATE='TX', COUNTRY='USA', LATITUDE=27.543739318847656, LONGITUDE=-99.46154022216797, rank=4),
#  Row(IATA_CODE='CRP', AIRPORT='Corpus Christi International Airport', CITY='Corpus Christi', STATE='TX', COUNTRY='USA', LATITUDE=27.770360946655273, LONGITUDE=-97.501220703125, rank=5),
#  Row(IATA_CODE='SAT', AIRPORT='San Antonio International Airport', CITY='San Antonio', STATE='TX', COUNTRY='USA', LATITUDE=29.533689498901367, LONGITUDE=-98.46977996826172, rank=6),
#  Row(IATA_CODE='HOU', AIRPORT='William P. Hobby Airport', CITY='Houston', STATE='TX', COUNTRY='USA', LATITUDE=29.64542007446289, LONGITUDE=-95.27889251708984, rank=7),
#  Row(IATA_CODE='BPT', AIRPORT='Jack Brooks Regional Airport\xa0(Southeast Texas Regional)', CITY='Beaumont/Port Arthur', STATE='TX', COUNTRY='USA', LATITUDE=29.950830459594727, LONGITUDE=-94.02069091796875, rank=8),
#  Row(IATA_CODE='IAH', AIRPORT='George Bush Intercontinental Airport', CITY='Houston', STATE='TX', COUNTRY='USA', LATITUDE=29.980470657348633, LONGITUDE=-95.3397216796875, rank=9),
#  Row(IATA_CODE='AUS', AIRPORT='Austin-Bergstrom International Airport', CITY='Austin', STATE='TX', COUNTRY='USA', LATITUDE=30.194530487060547, LONGITUDE=-97.66986846923828, rank=10),
#  Row(IATA_CODE='CLL', AIRPORT='Easterwood Airport', CITY='College Station', STATE='TX', COUNTRY='USA', LATITUDE=30.588590621948242, LONGITUDE=-96.36382293701172, rank=11),
#  Row(IATA_CODE='GRK', AIRPORT='Killeen-Fort Hood Regional Airport', CITY='Killeen', STATE='TX', COUNTRY='USA', LATITUDE=31.064899444580078, LONGITUDE=-97.82779693603516, rank=12),
#  Row(IATA_CODE='SJT', AIRPORT='San Angelo Regional Airport\xa0(Mathis Field)', CITY='San Angelo', STATE='TX', COUNTRY='USA', LATITUDE=31.357749938964844, LONGITUDE=-100.49630737304688, rank=13),
#  Row(IATA_CODE='ACT', AIRPORT='Waco Regional Airport', CITY='Waco', STATE='TX', COUNTRY='USA', LATITUDE=31.611289978027344, LONGITUDE=-97.23052215576172, rank=14),
#  Row(IATA_CODE='ELP', AIRPORT='El Paso International Airport', CITY='El Paso', STATE='TX', COUNTRY='USA', LATITUDE=31.806669235229492, LONGITUDE=-106.3778076171875, rank=15),
#  Row(IATA_CODE='MAF', AIRPORT='Midland International Airport', CITY='Midland', STATE='TX', COUNTRY='USA', LATITUDE=31.942529678344727, LONGITUDE=-102.20191192626953, rank=16),
#  Row(IATA_CODE='TYR', AIRPORT='Tyler Pounds Regional Airport', CITY='Tyler', STATE='TX', COUNTRY='USA', LATITUDE=32.35414123535156, LONGITUDE=-95.40238952636719, rank=17),
#  Row(IATA_CODE='GGG', AIRPORT='East Texas Regional Airport', CITY='Longview', STATE='TX', COUNTRY='USA', LATITUDE=32.38486099243164, LONGITUDE=-94.71170806884766, rank=18),
#  Row(IATA_CODE='ABI', AIRPORT='Abilene Regional Airport', CITY='Abilene', STATE='TX', COUNTRY='USA', LATITUDE=32.411319732666016, LONGITUDE=-99.68190002441406, rank=19),
#  Row(IATA_CODE='DAL', AIRPORT='Dallas Love Field', CITY='Dallas', STATE='TX', COUNTRY='USA', LATITUDE=32.847110748291016, LONGITUDE=-96.85176849365234, rank=20),
#  Row(IATA_CODE='DFW', AIRPORT='Dallas/Fort Worth International Airport', CITY='Dallas-Fort Worth', STATE='TX', COUNTRY='USA', LATITUDE=32.89595031738281, LONGITUDE=-97.03720092773438, rank=21),
#  Row(IATA_CODE='LBB', AIRPORT='Lubbock Preston Smith International Airport', CITY='Lubbock', STATE='TX', COUNTRY='USA', LATITUDE=33.663639068603516, LONGITUDE=-101.8227767944336, rank=22),
#  Row(IATA_CODE='SPS', AIRPORT='Wichita Falls Municipal Airport/Sheppard AFB', CITY='Wichita Falls', STATE='TX', COUNTRY='USA', LATITUDE=33.988800048828125, LONGITUDE=-98.49188995361328, rank=23),
#  Row(IATA_CODE='AMA', AIRPORT='Rick Husband Amarillo International Airport', CITY='Amarillo', STATE='TX', COUNTRY='USA', LATITUDE=35.2193717956543, LONGITUDE=-101.7059326171875, rank=24),
#  Row(IATA_CODE='SGU', AIRPORT='St. George Regional Airport', CITY='St George', STATE='UT', COUNTRY='USA', LATITUDE=37.090579986572266, LONGITUDE=-113.59306335449219, rank=1),
#  Row(IATA_CODE='CDC', AIRPORT='Cedar City Regional Airport', CITY='Cedar City', STATE='UT', COUNTRY='USA', LATITUDE=37.70096969604492, LONGITUDE=-113.09857940673828, rank=2),
#  Row(IATA_CODE='CNY', AIRPORT='Canyonlands Field', CITY='Moab', STATE='UT', COUNTRY='USA', LATITUDE=38.75495910644531, LONGITUDE=-109.75483703613281, rank=3),
#  Row(IATA_CODE='VEL', AIRPORT='Valdez Airport', CITY='Vernal', STATE='UT', COUNTRY='USA', LATITUDE=40.44089889526367, LONGITUDE=-109.50991821289062, rank=4),
#  Row(IATA_CODE='SLC', AIRPORT='Salt Lake City International Airport', CITY='Salt Lake City', STATE='UT', COUNTRY='USA', LATITUDE=40.78839111328125, LONGITUDE=-111.97776794433594, rank=5),
#  Row(IATA_CODE='ORF', AIRPORT='Norfolk International Airport', CITY='Norfolk', STATE='VA', COUNTRY='USA', LATITUDE=36.89461135864258, LONGITUDE=-76.20121765136719, rank=1),
#  Row(IATA_CODE='PHF', AIRPORT='Newport News/Williamsburg International Airport', CITY='Newport News', STATE='VA', COUNTRY='USA', LATITUDE=37.131900787353516, LONGITUDE=-76.49298858642578, rank=2),
#  Row(IATA_CODE='ROA', AIRPORT='Roanoke Regional Airport\xa0(Woodrum Field)', CITY='Roanoke', STATE='VA', COUNTRY='USA', LATITUDE=37.325469970703125, LONGITUDE=-79.97543334960938, rank=3),
#  Row(IATA_CODE='RIC', AIRPORT='Richmond International Airport', CITY='Richmond', STATE='VA', COUNTRY='USA', LATITUDE=37.50516891479492, LONGITUDE=-77.31967163085938, rank=4),
#  Row(IATA_CODE='CHO', AIRPORT='Charlottesville-Albemarle Airport', CITY='Charlottesville', STATE='VA', COUNTRY='USA', LATITUDE=38.138641357421875, LONGITUDE=-78.4528579711914, rank=5),
#  Row(IATA_CODE='DCA', AIRPORT='Ronald Reagan Washington National Airport', CITY='Arlington', STATE='VA', COUNTRY='USA', LATITUDE=38.852081298828125, LONGITUDE=-77.0377197265625, rank=6),
#  Row(IATA_CODE='IAD', AIRPORT='Washington Dulles International Airport', CITY='Chantilly', STATE='VA', COUNTRY='USA', LATITUDE=38.94453048706055, LONGITUDE=-77.455810546875, rank=7),
#  Row(IATA_CODE='STX', AIRPORT='Henry E. Rohlsen Airport', CITY='Christiansted', STATE='VI', COUNTRY='USA', LATITUDE=17.70189094543457, LONGITUDE=-64.7985610961914, rank=1),
#  Row(IATA_CODE='STT', AIRPORT='Cyril E. King Airport', CITY='Charlotte Amalie', STATE='VI', COUNTRY='USA', LATITUDE=18.337310791015625, LONGITUDE=-64.97335815429688, rank=2),
#  Row(IATA_CODE='BTV', AIRPORT='Burlington International Airport', CITY='Burlington', STATE='VT', COUNTRY='USA', LATITUDE=44.472999572753906, LONGITUDE=-73.15030670166016, rank=1),
#  Row(IATA_CODE='PSC', AIRPORT='Tri-Cities Airport', CITY='Pasco', STATE='WA', COUNTRY='USA', LATITUDE=46.264678955078125, LONGITUDE=-119.11903381347656, rank=1),
#  Row(IATA_CODE='SEA', AIRPORT='Seattle-Tacoma International Airport', CITY='Seattle', STATE='WA', COUNTRY='USA', LATITUDE=47.448978424072266, LONGITUDE=-122.30931091308594, rank=2),
#  Row(IATA_CODE='GEG', AIRPORT='Spokane International Airport', CITY='Spokane', STATE='WA', COUNTRY='USA', LATITUDE=47.6198616027832, LONGITUDE=-117.5338363647461, rank=3),
#  Row(IATA_CODE='BLI', AIRPORT='Bellingham International Airport', CITY='Bellingham', STATE='WA', COUNTRY='USA', LATITUDE=48.79275131225586, LONGITUDE=-122.53752899169922, rank=4),
#  Row(IATA_CODE='MKE', AIRPORT='General Mitchell International Airport', CITY='Milwaukee', STATE='WI', COUNTRY='USA', LATITUDE=42.94721984863281, LONGITUDE=-87.8965835571289, rank=1),
#  Row(IATA_CODE='MSN', AIRPORT='Dane County Regional Airport', CITY='Madison', STATE='WI', COUNTRY='USA', LATITUDE=43.13985824584961, LONGITUDE=-89.33750915527344, rank=2),
#  Row(IATA_CODE='LSE', AIRPORT='La Crosse Regional Airport', CITY='La Crosse', STATE='WI', COUNTRY='USA', LATITUDE=43.87937927246094, LONGITUDE=-91.25653839111328, rank=3),
#  Row(IATA_CODE='ATW', AIRPORT='Appleton International Airport', CITY='Appleton', STATE='WI', COUNTRY='USA', LATITUDE=44.257408142089844, LONGITUDE=-88.51947784423828, rank=4),
#  Row(IATA_CODE='GRB', AIRPORT='Green Bay-Austin Straubel International Airport', CITY='Green Bay', STATE='WI', COUNTRY='USA', LATITUDE=44.485069274902344, LONGITUDE=-88.12959289550781, rank=5),
#  Row(IATA_CODE='CWA', AIRPORT='Central Wisconsin Airport', CITY='Mosinee', STATE='WI', COUNTRY='USA', LATITUDE=44.777618408203125, LONGITUDE=-89.66677856445312, rank=6),
#  Row(IATA_CODE='EAU', AIRPORT='Chippewa Valley Regional Airport', CITY='Eau Claire', STATE='WI', COUNTRY='USA', LATITUDE=44.86526107788086, LONGITUDE=-91.48506927490234, rank=7),
#  Row(IATA_CODE='RHI', AIRPORT='Rhinelander-Oneida County Airport', CITY='Rhinelander', STATE='WI', COUNTRY='USA', LATITUDE=45.63119125366211, LONGITUDE=-89.46745300292969, rank=8),
#  Row(IATA_CODE='CRW', AIRPORT='Yeager Airport', CITY='Charleston', STATE='WV', COUNTRY='USA', LATITUDE=38.37314987182617, LONGITUDE=-81.59319305419922, rank=1),
#  Row(IATA_CODE='LAR', AIRPORT='Laramie Regional Airport', CITY='Laramie', STATE='WY', COUNTRY='USA', LATITUDE=41.312049865722656, LONGITUDE=-105.67498779296875, rank=1),
#  Row(IATA_CODE='RKS', AIRPORT='Rock Springs-Sweetwater County Airport', CITY='Rock Springs', STATE='WY', COUNTRY='USA', LATITUDE=41.59421920776367, LONGITUDE=-109.06519317626953, rank=2),
#  Row(IATA_CODE='CPR', AIRPORT='Natrona County International Airport', CITY='Casper', STATE='WY', COUNTRY='USA', LATITUDE=42.90835952758789, LONGITUDE=-106.46446990966797, rank=3),
#  Row(IATA_CODE='JAC', AIRPORT='Jackson Hole Airport', CITY='Jackson', STATE='WY', COUNTRY='USA', LATITUDE=43.60731887817383, LONGITUDE=-110.73773956298828, rank=4),
#  Row(IATA_CODE='GCC', AIRPORT='Gillette-Campbell County Airport', CITY='Gillette', STATE='WY', COUNTRY='USA', LATITUDE=44.348899841308594, LONGITUDE=-105.53936004638672, rank=5),
#  Row(IATA_CODE='COD', AIRPORT='Yellowstone Regional Airport', CITY='Cody', STATE='WY', COUNTRY='USA', LATITUDE=44.52019119262695, LONGITUDE=-109.0238037109375, rank=6)]

# %% [markdown]
# ### Ecriture de fichiers

# %%
window_df.write.option("header", True).csv("./work/data/window_df.csv")
window_df.write.parquet("./work/data/window_df.parquet")
window_df.rdd.getNumPartitions()

window_df_repartitionned = window_df.repartition(4)
window_df_repartitionned.write.option("header", True).csv("./work/window/window_df_repartionned.csv")
